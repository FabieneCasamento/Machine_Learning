# %% [markdown]
# # Árvores de decisão para problemas de Regressão.

# %% [markdown]
# Semelhante a árvode de decisão para a classificação.
#
# Montagem da entropia, para a árvore
#
# Base idade e anos de estudo (x) prever o salário da pessoa (y). Duas variáveis diferentes para fazer a previsão.
#
# Números calculados, mas no exemplo é apenas ilustrativo.
#
# Valores da média
#
# conceitos de entropia, ganhos de informação, resṕota 49 de salário, ou 4900.

# %% [markdown]
# ![image.png](attachment:e459269c-3260-4a44-b2e6-aedd54b710c8.png)
