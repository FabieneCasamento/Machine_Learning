# %% [markdown]
# ## 30.2) Detecção de outliers

# %% [markdown]
# ambiente anaconda Udemy

# %% [markdown]
# comando linux:
#
#  find -name 'census.csv'
#
# resposta
#
# ./Machine_Learning_Udemy/24-Dados_desbalanceados/census.csv
#
# find -name 'credit'
#
# sem nada
#
# $ find -name '*credit*'$
#
# ./Machine_Learning_Udemy/27-Deteccao_de_outliers/credit_data.csv
#
# ./Machine_Learning_Udemy/2-3-Classificacao/credit_risk_dataset.csv

# %% [markdown]
# # Detecção de outliers

# %% [markdown]
# ## Boxplot

# %%
import pandas as pd

# %%
base_credit = pd.read_csv('credit_data.csv')
base_credit.tail()
# Out:
#       clientid        income        age         loan  default
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0

# %%
base_credit_2 = pd.read_csv('../../Machine_Learning_Udemy/2-3-Classificacao/credit_risk_dataset.csv')
base_credit_2.tail()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# 32576                 0.11                         N
# 32577                 0.15                         N
# 32578                 0.46                         N
# 32579                 0.10                         N
# 32580                 0.15                         N
#
#        cb_person_cred_hist_length
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30

# %% [markdown]
# default => 0 cliente paga e 1 cliente não paga o imprestimo.

# %% [markdown]
# verificar os dados faltantes

# %%
base_credit.isnull().sum()
# Out:
# clientid    0
# income      0
# age         3
# loan        0
# default     0
# dtype: int64

# %% [markdown]
# 3 dados da idade que não foi preenchida.

# %% [markdown]
# apagaremos os dados nulos, para não ocorrer erro nos processos.

# %%
base_credit.loc[base_credit['age'].isnull()]
# Out:
#     clientid        income  age         loan  default
# 28        29  59417.805406  NaN  2082.625938        0
# 30        31  48528.852796  NaN  6155.784670        0
# 31        32  23526.302555  NaN  2862.010139        0

# %%
base_credit.dropna(inplace=True)

# %% [markdown]
# verificamos que não há nenhum registro nulo nos processos

# %%
base_credit.isnull().sum()
# Out:
# clientid    0
# income      0
# age         0
# loan        0
# default     0
# dtype: int64

# %% [markdown]
# # Outliers idade

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Outliers idade
grafico = px.box(base_credit, y = 'age')
grafico.show()

# %% [markdown]
# ![image.png](attachment:4ee8912c-5a49-4081-a80d-b38c1b6c421e.png)

# %% [markdown]
# ![image.png](attachment:15533181-7856-4e76-9bcf-7ffe60cf2f22.png)

# %%
# Outliers idade
grafico = px.box(base_credit_2, y = 'person_age')
grafico.show()

# %% [markdown]
# ![image.png](attachment:abab2b19-9437-4a94-b92c-9f50a93b560c.png)

# %% [markdown]
# ![image.png](attachment:ff8f4950-55c4-4857-aaa5-ddcb16f6042b.png)

# %% [markdown]
# ### a mediana é o valor que está no meio dos dados, diferente da média.

# %%
len(base_credit)
# Out:
# 1997

# %%
# saber o valor que está na mediana

# %%
len(base_credit)/2
# Out:
# 998.5

# %%
1997 / 2
# Out:
# 998.5

# %%
base_credit_mediana = base_credit.reset_index(drop=True)
print()
#Primeiro pegamos o rótulo/ID do índice
indice_alvo = base_credit_mediana.index[998]
print('indice')
print(indice_alvo)
# Buscamos a linha inteira por esse rótulo
print()
linha = base_credit_mediana.loc[indice_alvo]
print(linha)
# Out:
# indice
# 998
#
# clientid     1002.000000
# income      62422.203789
# age            32.145221
# loan         2841.633423
# default         0.000000
# Name: 998, dtype: float64

# %%
linha = base_credit_mediana.loc[999]
print(linha)
# Out:
# clientid     1003.000000
# income      63166.994955
# age            56.510040
# loan         4058.789534
# default         0.000000
# Name: 999, dtype: float64

# %%
base_credit.loc[999]
# Out:
# clientid     1000.000000
# income      62165.861186
# age            19.602543
# loan         4739.948954
# default         0.000000
# Name: 999, dtype: float64

# %%
base_credit.loc[998]
# Out:
# clientid      999.000000
# income      36192.149452
# age            21.402403
# loan         7236.173930
# default         1.000000
# Name: 998, dtype: float64

# %%
plt.hist(base_credit['age'], bins=5, color='skyblue', edgecolor='black')
plt.title('Meu Histograma - Matplotlib')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# mediana ~ 41

# %%
plt.hist(base_credit['age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Meu Histograma - Matplotlib')
plt.xlabel('Valores')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# primeiro quartil e o terceiro quartil q1 e q3,
#
# q1 idade em que está em 25% dos registros.
#
# e o q3 idade que está na posição dos 75% dos registros.

# %% [markdown]
# pontos fora são os ouliers:
#
# ### dados fora do upper fence e lower fence.

# %%
# Outliers idade
outliers_age = base_credit[base_credit['age'] < -20]
outliers_age
# Out:
#     clientid        income        age         loan  default
# 15        16  50501.726689 -28.218361  3977.287432        0
# 21        22  32197.620701 -52.423280  4244.057136        0
# 26        27  63287.038908 -36.496976  9595.286289        0

# %% [markdown]
# considerados outliers

# %%
outliers_age = base_credit[base_credit['age'] < 0]
outliers_age
# Out:
#     clientid        income        age         loan  default
# 15        16  50501.726689 -28.218361  3977.287432        0
# 21        22  32197.620701 -52.423280  4244.057136        0
# 26        27  63287.038908 -36.496976  9595.286289        0

# %% [markdown]
# Identificar ou detectar fraude da empresa.

# %% [markdown]
# fraude em cartão de crédito, seleciona as transações que saem do padrão, indicando ao setor responsável para que o stero faça a análise para verificar de fato se fogem realmente do padrão.

# %% [markdown]
# ### Outliers loan / dívida

# %%
# Outliers loan
grafico = px.box(base_credit, y='loan')
grafico.show()

# %% [markdown]
# ![image.png](attachment:9d5b6322-b803-41db-852a-90dd583e2886.png)

# %% [markdown]
# ![image.png](attachment:0eba061a-4392-49a5-9dfd-17d4361a7afa.png)

# %% [markdown]
# ![image.png](attachment:9d40c814-2f20-4cde-b3c5-bb51a91ca527.png)

# %% [markdown]
# inserir os dados ao setor responsável

# %%
outliers_loan = base_credit[base_credit['loan'] > 13300] # DE ACORDO COM A VISUALIZAÇÃO box plot
outliers_loan
# Out:
#       clientid        income        age          loan  default
# 1378      1379  69755.320163  44.543682  13766.051239        0
# 1584      1585  67289.585683  26.727400  13376.797706        1
# 1801      1802  67802.694456  49.037987  13443.473176        0

# %%
outliers_loan = base_credit[base_credit['loan'] > 13190] # DE ACORDO COM A VISUALIZAÇÃO box plot, teste
outliers_loan
# Out:
#       clientid        income        age          loan  default
# 1050      1051  69456.567771  48.053557  13190.365886        0
# 1378      1379  69755.320163  44.543682  13766.051239        0
# 1584      1585  67289.585683  26.727400  13376.797706        1
# 1801      1802  67802.694456  49.037987  13443.473176        0

# %%
outliers_loan = base_credit[base_credit['loan'] > 13191] # DE ACORDO COM A VISUALIZAÇÃO box plot1
outliers_loan
# Out:
#       clientid        income        age          loan  default
# 1378      1379  69755.320163  44.543682  13766.051239        0
# 1584      1585  67289.585683  26.727400  13376.797706        1
# 1801      1802  67802.694456  49.037987  13443.473176        0

# %% [markdown]
# Outliers
#
# - Valores anormais
#
# - valores fora do padrão (afastados da média)
#
# Fogem do valor da média, valores anormais, como uma variável (boxplot)
#
# além do gráfico de dispersão. 2 atributos juntos e identifica valor fora do padrão (outliers). Precisamos de 2 variáveis.
#
#
# => Causas
#
# - Acaso
#
# - Erro no preenchimento dos dados
#
# - Fraudes. (Problemas no cartão de crédito → Fraude)
#
#
# =>Tratamentos
#
# ver que é fraude, entra em contato com o cliente
#
# Remover o registro, problema também, pois pode remover um dado valioso.
#
# Não fazer nada, mas é ruim, se usarmos o modelo de regressão, atrapalha a aprendizagem de máquina,
#
# substituir os dados, usar a média dos dados substituir no processo onde houver outliers

# %% [markdown]
# ![image.png](attachment:9a811253-3d3a-47dc-951e-07e7c69963fa.png)

# %% [markdown]
# ## 30.3) Gráfico de dispersão

# %% [markdown]
# Usaremos 2 atributos, colunas preditoras

# %% [markdown]
# # Income x age

# %%
# Income x age  # x (renda - income) e y age anos
grafico = px.scatter(x = base_credit['income'], y = base_credit['age'])
grafico.show()

# %% [markdown]
# ![image.png](attachment:b87039d0-edcb-49c1-b000-8f89897899bc.png)

# %% [markdown]
# Outros atributos

# %% [markdown]
# trocando os nomes dos atributos

# %% [markdown]
# # Income x loan

# %%
# Income x loan
grafico = px.scatter(x = base_credit['income'], y = base_credit['loan'])
grafico.show()

# %% [markdown]
# ![image.png](attachment:a802c5be-c81a-4a45-8ee8-0252c48a0991.png)

# %% [markdown]
# ### maior a renda maior a dívida, sem dados de outliers

# %%
#import plotly.express as px

grafico = px.scatter(x = base_credit['income'], y = base_credit['loan'])

# Atualizando o layout 
grafico.update_layout(
    title='Relação entre Renda e Empréstimo',
    xaxis_title='Renda (Income)',
    yaxis_title='Empréstimo (Loan)'
)

grafico.show()

# %% [markdown]
# ![image.png](attachment:9ad1a343-ca05-4b9e-a02e-453db5b7e5be.png)

# %% [markdown]
# # Age x loan

# %%
# Age x loan
grafico = px.scatter(x = base_credit['age'], y = base_credit['loan'])
# Atualizando o layout 
grafico.update_layout(
    title='Relação entre Idade e Empréstimo',
    xaxis_title='Idade (Age)',
    yaxis_title='Empréstimo (Loan)'
)


grafico.show()

# %% [markdown]
# ![image.png](attachment:5dd76cdb-fb87-4e06-8308-2d2034f3a5e9.png)

# %% [markdown]
# ![image.png](attachment:b7eb8401-f9a5-4765-8b12-1fea89e9f454.png)

# %% [markdown]
# no linux
#
# find -name 'census.csv'
#
# ./Documentos/Fabiene/UDEMY_ML/Machine_Learning_Udemy/24-Dados_desbalanceados/census.csv

# %%
base_census = pd.read_csv('../24-Dados_desbalanceados/census.csv')
base_census.tail(7)
# Out:
#        age      workclass  final-weight      education  education-num  \
# 32554   53        Private        321865        Masters             14
# 32555   22        Private        310152   Some-college             10
# 32556   27        Private        257302     Assoc-acdm             12
# 32557   40        Private        154374        HS-grad              9
# 32558   58        Private        151910        HS-grad              9
# 32559   22        Private        201490        HS-grad              9
# 32560   52   Self-emp-inc        287927        HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 32554   Married-civ-spouse     Exec-managerial         Husband   White
# 32555        Never-married     Protective-serv   Not-in-family   White
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            sex  capital-gain  capital-loos  hour-per-week  native-country  \
# 32554     Male             0             0             40   United-States
# 32555     Male             0             0             40   United-States
# 32556   Female             0             0             38   United-States
# 32557     Male             0             0             40   United-States
# 32558   Female             0             0             40   United-States
# 32559     Male             0             0             20   United-States
# 32560   Female         15024             0             40   United-States
#
#        income
# 32554    >50K
# 32555   <=50K
# 32556   <=50K
# 32557    >50K
# 32558   <=50K
# 32559   <=50K
# 32560    >50K

# %% [markdown]
# previsão se a pessoa ganha maios ou menos de 50 mil dólares.

# %% [markdown]
# Pontuação, de acordo com os dados de cada pessoa: final-weight

# %% [markdown]
# # Age x final weight

# %%
# Age x final weight
grafico = px.scatter(x = base_census['age'], y = base_census['final-weight'])

grafico.update_layout(
    title='Relação entre Idade e Pesos',
    xaxis_title='Idade (Age)',
    yaxis_title='Pesos (final-weight)'
)

grafico.show()

# %% [markdown]
# ![image.png](attachment:59ab2246-9ccc-4a1e-85ef-3a816bfe9daa.png)

# %% [markdown]
# maior para a direita, maior a idade, e quanto mais alta, mais peso e valor do final weight.
