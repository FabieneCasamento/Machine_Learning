# %% [markdown]
# # 32.6) PyCaret para Regressão
#
# ## Ambiente no Anaconda

# %%
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/pycaret-env/bin/python

# %% [markdown]
# ### Regressão temos o objetivo de prever um número

# %%
import numpy as np

# from pycaret.utils import enable_colab
# enable_colab()

# %% [markdown]
# ##### Base de dados

# %%
from pycaret.datasets import get_data
# base de dados
todas_bases = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection               NaN               NaN
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit               NaN
# 4       Classification (Binary)             Class               NaN
# 5       Classification (Binary)             Class               NaN
# 6       Classification (Binary)           default               NaN
# 7       Classification (Binary)    Class variable               NaN
# 8       Classification (Binary)             stabf               NaN
# 9       Classification (Binary)              left               NaN
# 10      Classification (Binary)             DEATH               NaN
# 11      Classification (Binary)           Disease               NaN
# 12      Classification (Binary)             Class               NaN
# 13      Classification (Binary)       income >50K               NaN
# 14      Classification (Binary)          Purchase               NaN
# 15      Classification (Binary)       TARGET_5Yrs               NaN
# 16      Classification (Binary)              type               NaN
# 17      Classification (Binary)             Class               NaN
# 18      Classification (Binary)          Survived               NaN
# 19      Classification (Binary)      party_winner               NaN
# 20  Classification (Multiclass)              Type               NaN
# 21  Classification (Multiclass)           species               NaN
# 22  Classification (Multiclass)             CLASS               NaN
# 23  Classification (Multiclass)     Next_Question               NaN
# 24  Classification (Multiclass)             Class               NaN
# 25  Classification (Multiclass)               NSP               NaN
# 26                   Clustering               NaN               NaN
# 27                   Clustering               NaN               NaN
# 28                   Clustering               NaN               NaN
# 29                   Clustering               NaN               NaN
# 30                   Clustering               NaN               NaN
# 31                   Clustering               NaN               NaN
# 32                   Clustering               NaN               NaN
# 33                   Clustering               NaN               NaN
# 34                   Clustering               NaN               NaN
# 35                   Clustering               NaN               NaN
# 36                   Clustering               NaN               NaN
# 37                   Clustering               NaN               NaN
# 38                   Clustering               NaN               NaN
# 39                          NLP             tweet               NaN
# 40         NLP / Classification        reviewText               NaN
# 41         NLP / Classification                en               NaN
# 42             NLP / Regression              text               NaN
# 43         NLP / Classification              Text               NaN
# 44                   Regression             price               NaN
# 45                   Regression               cnt               NaN
# 46                   Regression              medv               NaN
# 47                   Regression          strength               NaN
# 48                   Regression             Price               NaN
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area               NaN
# 51                   Regression         Gold_T+22               NaN
# 52                   Regression         SalePrice               NaN
# 53                   Regression           charges               NaN
# 54                   Regression               PPE               NaN
# 55                   Regression    traffic_volume               NaN
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
dataset = get_data('automobile')
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19     3.4              10.0        102
# 4          136         mpfi  3.19     3.4               8.0        115
#
#    peak-rpm city-mpg highway-mpg  price
# 0      5000       21          27  13495
# 1      5000       21          27  16500
# 2      5000       19          26  16500
# 3      5500       24          30  13950
# 4      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
list(dataset)

#make -tipo de carro
# 'fuel-type' combustível

# 'num-of-doors' número de portas
# 'body-style' estilo 


 # 'engine-type', tipo 
 # 'num-of-cylinders', número de cilindros

# por meio dos dados , prever o price

# ----------------------------------------------------------------
# problema no string, mas não precisamos fazer o pré processamento, no pycaret faz direto.
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
# automobile	Multivariate	Regression	price	NaN	202	26	Y

# %%
# características do veículo para prever o preço

# %%
type(dataset) # formato dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.shape
# Out:
# (202, 26)

# %%
# base => dataset

# definindo a base de treinamento
# fraca com base de 90% dos dados,
#para o registro, random_state, gera sempre a mesma semente, 1, o resultado é sempre o mesmo, rodando várias vezes
base_treinamento = dataset.sample(frac=0.9, random_state =1)

base_treinamento.shape
# Out:
# (182, 26)

# %%
# valor de index para subtrair, e gerar a base de teste
base_treinamento.index
# Out:
# Index([196,  95, 173, 123,  38,  94,  78,  58,  29,   4,
#        ...
#         22,  61,  63,   7, 198, 141,  86,  96,  68,  50],
#       dtype='int64', length=182)

# %%
base_teste = dataset.drop(base_treinamento.index)

# %%
base_teste.shape # registros restantes
# Out:
# (20, 26)

# %% [markdown]
#  ## Problema de regressão
#
#  ### Configuração do ambiente PyCaret

# %%
# base para o treinamento e indicamos o alvo que queremos prever (atributo que queremos prever).
# session_id = 1, para termos sempre o mesmo resultado (mesma ideia do random_state =1)

# abaixo estão os dados sobre o experimento

# Rows with missing values	19.2% linha com dados faltantes;

# %%
 from pycaret.regression import setup
 
 experimento = setup(data = base_treinamento, target = 'price', session_id = 1)
# Out:
# <style type="text/css">
# #T_be8d3_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_be8d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be8d3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_be8d3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be8d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be8d3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_be8d3_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_be8d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_be8d3_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_be8d3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_be8d3_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_be8d3_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_be8d3_row3_col1" class="data row3 col1" >(182, 26)</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_be8d3_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_be8d3_row4_col1" class="data row4 col1" >(182, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_be8d3_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_be8d3_row5_col1" class="data row5 col1" >(127, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_be8d3_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_be8d3_row6_col1" class="data row6 col1" >(55, 89)</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_be8d3_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_be8d3_row7_col1" class="data row7 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_be8d3_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_be8d3_row8_col1" class="data row8 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_be8d3_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_be8d3_row9_col1" class="data row9 col1" >19.2%</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_be8d3_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_be8d3_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_be8d3_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_be8d3_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_be8d3_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_be8d3_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_be8d3_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_be8d3_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_be8d3_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_be8d3_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_be8d3_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_be8d3_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_be8d3_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_be8d3_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_be8d3_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_be8d3_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_be8d3_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_be8d3_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_be8d3_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_be8d3_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_be8d3_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_be8d3_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_be8d3_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_be8d3_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_be8d3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_be8d3_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_be8d3_row22_col1" class="data row22 col1" >d003</td>
#     </tr>
#   </tbody>
# </table>

# %%
experimento

# %%
# Para ver essa tabela de novo a qualquer momento, use:
experimento.pull()
# Out:
#                     Description             Value
# 0                    Session id                 1
# 1                        Target             price
# 2                   Target type        Regression
# 3           Original data shape         (182, 26)
# 4        Transformed data shape         (182, 89)
# 5   Transformed train set shape         (127, 89)
# 6    Transformed test set shape          (55, 89)
# 7              Numeric features                11
# 8          Categorical features                14
# 9      Rows with missing values             19.2%
# 10                   Preprocess              True
# 11              Imputation type            simple
# 12           Numeric imputation              mean
# 13       Categorical imputation              mode
# 14     Maximum one-hot encoding                25
# 15              Encoding method              None
# 16               Fold Generator             KFold
# 17                  Fold Number                10
# 18                     CPU Jobs                -1
# 19                      Use GPU             False
# 20               Log Experiment             False
# 21              Experiment Name  reg-default-name
# 22                          USI              d003

# %%
# Ver quais colunas ele considerou numéricas
print("Numéricas:", experimento.get_config('X_train').select_dtypes(include=[np.number]).columns.tolist())

# Ver quais colunas ele considerou categóricas
print("Categóricas:", experimento.get_config('X_train').select_dtypes(exclude=[np.number]).columns.tolist())
# Out:
# Numéricas: ['symboling', 'normalized-losses', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-size', 'compression-ratio', 'city-mpg', 'highway-mpg']
# Categóricas: ['make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'engine-type', 'num-of-cylinders', 'fuel-system', 'bore', 'stroke', 'horsepower', 'peak-rpm']

# %%
#Numeric features	11, atributos ou colunas númericas

# Categorical features	14, atributos ou colunas categoricas, strings

# %% [markdown]
# ## treinamento de vários modelos com validação cruzada
#
# Machine Learning: Introdução a Validação Cruzada
#
# https://www.youtube.com/watch?v=RczbeFs_WbQ

# %%
# validação cruzada, criando os modelos que melhor seria utilizados para trabalhar com os dadis
from pycaret.regression import compare_models

modelos  = compare_models()
# Out:
# <style type="text/css">
# #T_7e08a th {
#   text-align: left;
# }
# #T_7e08a_row0_col0, #T_7e08a_row0_col5, #T_7e08a_row0_col6, #T_7e08a_row1_col0, #T_7e08a_row1_col1, #T_7e08a_row1_col2, #T_7e08a_row1_col3, #T_7e08a_row1_col4, #T_7e08a_row1_col5, #T_7e08a_row1_col6, #T_7e08a_row2_col0, #T_7e08a_row2_col1, #T_7e08a_row2_col2, #T_7e08a_row2_col3, #T_7e08a_row2_col4, #T_7e08a_row2_col5, #T_7e08a_row2_col6, #T_7e08a_row3_col0, #T_7e08a_row3_col1, #T_7e08a_row3_col2, #T_7e08a_row3_col3, #T_7e08a_row3_col4, #T_7e08a_row4_col0, #T_7e08a_row4_col1, #T_7e08a_row4_col2, #T_7e08a_row4_col3, #T_7e08a_row4_col4, #T_7e08a_row4_col5, #T_7e08a_row4_col6, #T_7e08a_row5_col0, #T_7e08a_row5_col1, #T_7e08a_row5_col2, #T_7e08a_row5_col3, #T_7e08a_row5_col4, #T_7e08a_row5_col5, #T_7e08a_row5_col6, #T_7e08a_row6_col0, #T_7e08a_row6_col1, #T_7e08a_row6_col2, #T_7e08a_row6_col3, #T_7e08a_row6_col4, #T_7e08a_row6_col5, #T_7e08a_row6_col6, #T_7e08a_row7_col0, #T_7e08a_row7_col1, #T_7e08a_row7_col2, #T_7e08a_row7_col3, #T_7e08a_row7_col4, #T_7e08a_row7_col5, #T_7e08a_row7_col6, #T_7e08a_row8_col0, #T_7e08a_row8_col1, #T_7e08a_row8_col2, #T_7e08a_row8_col3, #T_7e08a_row8_col4, #T_7e08a_row8_col5, #T_7e08a_row8_col6, #T_7e08a_row9_col0, #T_7e08a_row9_col1, #T_7e08a_row9_col2, #T_7e08a_row9_col3, #T_7e08a_row9_col4, #T_7e08a_row9_col5, #T_7e08a_row9_col6, #T_7e08a_row10_col0, #T_7e08a_row10_col1, #T_7e08a_row10_col2, #T_7e08a_row10_col3, #T_7e08a_row10_col4, #T_7e08a_row10_col5, #T_7e08a_row10_col6, #T_7e08a_row11_col0, #T_7e08a_row11_col1, #T_7e08a_row11_col2, #T_7e08a_row11_col3, #T_7e08a_row11_col4, #T_7e08a_row11_col5, #T_7e08a_row11_col6, #T_7e08a_row12_col0, #T_7e08a_row12_col1, #T_7e08a_row12_col2, #T_7e08a_row12_col3, #T_7e08a_row12_col4, #T_7e08a_row12_col5, #T_7e08a_row12_col6, #T_7e08a_row13_col0, #T_7e08a_row13_col1, #T_7e08a_row13_col2, #T_7e08a_row13_col3, #T_7e08a_row13_col4, #T_7e08a_row13_col5, #T_7e08a_row13_col6, #T_7e08a_row14_col0, #T_7e08a_row14_col1, #T_7e08a_row14_col2, #T_7e08a_row14_col3, #T_7e08a_row14_col4, #T_7e08a_row14_col5, #T_7e08a_row14_col6, #T_7e08a_row15_col0, #T_7e08a_row15_col1, #T_7e08a_row15_col2, #T_7e08a_row15_col3, #T_7e08a_row15_col4, #T_7e08a_row15_col5, #T_7e08a_row15_col6, #T_7e08a_row16_col0, #T_7e08a_row16_col1, #T_7e08a_row16_col2, #T_7e08a_row16_col3, #T_7e08a_row16_col4, #T_7e08a_row16_col5, #T_7e08a_row16_col6, #T_7e08a_row17_col0, #T_7e08a_row17_col1, #T_7e08a_row17_col2, #T_7e08a_row17_col3, #T_7e08a_row17_col4, #T_7e08a_row17_col5, #T_7e08a_row17_col6 {
#   text-align: left;
# }
# #T_7e08a_row0_col1, #T_7e08a_row0_col2, #T_7e08a_row0_col3, #T_7e08a_row0_col4, #T_7e08a_row3_col5, #T_7e08a_row3_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_
col7" >0.0590</td>
#     </tr>
#     <tr>
#       <th id="T_7e08a_level0_row5" class="row_heading level0 row5" >lr</th>
#       <td id="T_7e08a_row5_col0" class="data row5 col0" >Linear Regression</td>
#       <td id="T_7e08a_row5_col1" class="data row5 col1" >2450.0982</td>
#       <td id="T_7e08a_row5_col2" class="data row5 col2" >11211308.7115</td>
#       <td id="T_7e08a_row5_col3" class="data row5 col3" >3192.2701</td>
#       <td id="T_7e08a_row5_col4" class="data row5 col4" >0.7841</td>
#       <td id="T_7e08a_row5_col5" class="data row5 col5" >0.2756</td>
#       <td id="T_7e08a_row5_col6" class="data row5 col6" >0.2079</td>
#       <td id="T_7e08a_row5_col7" class="data row5 col7" >0

# %% [markdown]
# Algorimos com os testes, e os melhores resultados

# %%
 #	        Model	             MAE	MSE	          RMSE	          R2	RMSLE	MAPE	TT (Sec)
#	Lasso Regression	2246.0830	8981652.1742	2906.6047	0.8349	0.2232	0.1851	0.2180

# %%
#                               RMSLE	MAPE
#et Extra Trees Regressor		0.2112	0.1659

# %% [markdown]
# #### Métricas conhecidas quando avaliamos os algoritmos da Regressão
#
# Isso depois de fazer a validação cruzada que foi cortada por 10 pedaços, ou divido em 10 folds para cada algoritmo.

# %%
# --- ANÁLISE COMPARATIVA DE RESULTADOS (REGRESSÃO) ---

# MAE (Mean Absolute Error): Erro médio absoluto em valor real. 
# Indica quanto o modelo erra, em média, no preço (ex: erra por +- R$ 500,00).

# MSE (Mean Squared Error) & RMSE (Root Mean Squared Error):
# Penalizam erros grandes. Se o RMSE estiver muito maior que o MAE, 
# o modelo está errando feio em alguns preços específicos (outliers).

# R2 (R-Squared): Coeficiente de Determinação. 
# Indica quanto da variação do preço o modelo explica. 1.0 é o ideal (100%).
# Se for 0.80, o modelo explica 80% do fenômeno dos preços.

# RMSLE (Root Mean Squared Logarithmic Error): 
# Útil quando o preço varia de valores muito pequenos a muito grandes. 
# Penaliza mais subestimar o preço do que superestimar.

# MAPE (Mean Absolute Percentage Error): Erro médio em porcentagem.
# Se o MAPE é 0.10, o modelo erra cerca de 10% do valor do produto.

# TT (Sec): Tempo de Treinamento. 
# Crucial para modelos em produção que precisam de re-treino constante.

# --- PERFORMANCE DOS MODELOS ---

# 1. Random Forest / LGBM: Geralmente dominam o R2 e RMSE por captarem relações 
# não-lineares complexas entre as características e o preço.

# 2. KNN: Pode ter um MAE baixo, mas sofre se não houver normalização, 
# pois distâncias entre preços altos e baixos variam drasticamente.

# 3. LDA/QDA: (Se usados como Regressores Logísticos em faixas de preço) 
# São mais rígidos e costumam ter métricas piores se o preço flutuar muito.

# %% [markdown]
# Olhe primeiro para o R2: É a forma mais rápida de ver quem "entendeu" melhor o nosso banco de dados.
#
# Comparar MAE vs RMSE: Se o RMSE for muito maior, seu modelo está tendo dificuldades com preços muito fora do padrão (muito caros ou muito baratos).
#
# Verificar o MAPE: Ele é o mais fácil de explicar para um cliente. "Nosso modelo erra o preço em apenas X%".

# %%
#experimento.plot_model('modelo?', plot='error')

# %% [markdown]
# 1. Lasso Regression (Least Absolute Shrinkage and Selection Operator)
#
# O Lasso é uma versão da Regressão Linear que tem um "superpoder": ele consegue zerar colunas que não servem para nada.

# %%
# Lasso Regression:
# Uma regressão linear que aplica penalidade (L1) aos coeficientes.
# Ponto forte: Seleção automática de variáveis. Se uma coluna não ajuda a prever o preço, 
# o Lasso reduz o peso dela a zero, simplificando o modelo.
# Ideal para: Quando temo muitas colunas e suspeita que poucas são realmente importantes.
# Sensibilidade: Precisa que os dados estejam na mesma escala (StandardScaler).

# %% [markdown]
# 2. Extra Trees Regressor (Extremely Randomized Trees)
#
# Ele é o "primo" mais radical do Random Forest. Enquanto o Random Forest procura o melhor corte para cada galho, o Extra Trees escolhe cortes de forma totalmente aleatória e depois seleciona o melhor entre esses aleatórios.

# %%
# Extra Trees Regressor:
# Similar ao Random Forest, mas com mais aleatoriedade na criação das divisões das árvores.
# Ponto forte: Reduz a variância e o risco de overfitting melhor que o Random Forest padrão.
# Velocidade: Costuma ser mais rápido que o Random Forest porque não precisa "calcular" o 
# melhor corte matematicamente, ele testa alguns aleatórios e escolhe o melhor.
# Ideal para: Dados com muito ruído onde o Random Forest está "decorando" demais os erros.

# %%
modelos
# Out:
# Lasso(random_state=1)

# %%
modelos.get_params() # do lasso
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'positive': False,
#  'precompute': False,
#  'random_state': 1,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %% [markdown]
# Valer mais para considerar o R2,
#
#
# olhar também os modelos tradicionais Linear Regression (lr - Linear Regression), mas teve pouca performance no R2.
#
# Fazer o tuning dos modelos, para escolher os melhores parâmetros, para aumentar o desempenho.

# %% [markdown]
# Decision Tree Rgressor => Decision Tree Regressar, baseada em árvores de decisão (Decision Tree Regressor - dt)
#
# Valor R2  = 0,7077, vamos tentar aumentar a performance e desempenho, fazendo o tuning dos parâmetros no modelo

# %% [markdown]
# ### Tuning dos modelos

# %% [markdown]
# ### escolhido o modelo para Decision Tree Regressor - dt

# %%
from pycaret.regression import create_model

dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_9db04_row10_col0, #T_9db04_row10_col1, #T_9db04_row10_col2, #T_9db04_row10_col3, #T_9db04_row10_col4, #T_9db04_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9db04">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9db04_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9db04_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9db04_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9db04_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9db04_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9db04_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9db04_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9db04_row0_col0" class="data row0 col0" >2350.4615</td>
#       <td id="T_9db04_row0_col1" class="data row0 col1" >11474637.5385</td>
#       <td id="T_9db04_row0_col2" class="data row0 col2" >3387.4234</td>
#       <td id="T_9db04_row0_col3" class="data row0 col3" >0.5777</td>
#       <td id="T_9db04_row0_col4" class="data row0 col4" >0.2862</td>
#       <td id="T_9db04_row0_col5" class="data row0 col5" >0.2392</td>
#     </tr>
#     <tr>
#       <th id="T_9db04_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9db04_row1_col0" class="data row1 col0" >2920.0769</td>
#       <td id="T_9db04_row1_col1" class="data row1 col1" >13155295.9231</td>
#       <td id="T_9db04_row1_col2" class="data row1 col2" >3627.0230</td>
#       <td id="T_9db04_row1_col3" class="data row1 col3" >0.7144</td>
#       <td id="T_9db04_row1_col4" class="data row1 col4" >0.2317</td>
#       <td id="T_9db04_row1_col5" class="data row1 col5" >0.2040</td>
#     </tr>
#     <tr>
#       <th id="T_9db04_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_9db04_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9db04_row9_col0" class="data row9 col0" >2178.6667</td>
#       <td id="T_9db04_row9_col1" class="data row9 col1" >8271035.5000</td>
#       <td id="T_9db04_row9_col2" class="data row9 col2" >2875.9408</td>
#       <td id="T_9db04_row9_col3" class="data row9 col3" >0.7822</td>
#       <td id="T_9db04_row9_col4" class="data row9 col4" >0.2006</td>
#       <td id="T_9db04_row9_col5" class="data row9 col5" >0.1649</td>
#     </tr>
#     <tr>
#       <th id="T_9db04_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9db04_row10_col0" class="data row10 col0" >2863.4288</td>
#       <td id="T_9db04_row10_col1" class="data row10 col1" >20441918.3737</td>
#       <td id="T_9db04_row10_col2" class="data row10 col2" >4134.5983</td>
#       <td id="T_9db04_row10_col3" class="data row10 col3" >0.7077</td>
#       <td id="T_9db04_row10_col4" class="data row10 col4" >0.2676</td>
#       <td id="T_9db04_row10_col5" class="data row10 col5" >0.2078</td>
#     </tr>
#     <tr>
#       <th id="T_9db04_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9db04_row11_col0" class="data row11 col0" >922.2945</td>
#       <td id="T_9db04_row11_col1" class="data row11 col1" >22973190.7718</td>
#       <td id="T_9db04_row11_col2" class="data row11 col2" >1829.4849</td>
#       <td id="T_9db04_row11_col3" class="data row11 col3" >0.1434</td>
#       <td id="T_9db04_row11_col4" class="data row11 col4" >0.0545</td>
#       <td id="T_9db04_row11_col5" class="data row11 col5" >0.0357</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# escolhido o modelo com a validação cruzada (com os 10 folds) e os dados da base da escolha.

# %%
dt
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
dt.get_params() # parâmetros utilizados
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 1,
#  'splitter': 'best'}

# %% [markdown]
# A Decision Tree Regressor (Árvore de Decisão para Regressão) funciona criando uma série de perguntas "sim ou não" sobre os dados para chegar a um valor numérico final (como o preço). Diferente da classificação, aqui o resultado final em cada folha é a média dos valores dos dados que caíram ali.

# %%
# --- Decision Tree Regressor (Parâmetros) ---

# criterion='squared_error': Métrica para medir a qualidade do corte. 
# O 'erro quadrático' busca reduzir a variância dentro de cada nó (média das previsões).

# splitter='best': Escolhe a melhor divisão possível em cada nó. 
# Alternativa: 'random' (escolhe um corte aleatório, sendo mais rápido e evitando overfitting).

# max_depth=None: A árvore cresce até que todas as folhas sejam puras ou 
# contenham menos que 'min_samples_split'. Cuidado: sem limite causa Overfitting.

# min_samples_split=2: O número mínimo de amostras que um nó deve ter 
# para ser dividido em dois novos galhos.

# min_samples_leaf=1: O número mínimo de amostras que deve existir em 
# cada "folha" (final da árvore). Valores maiores suavizam o modelo.

# max_features=None: Considera todas as colunas (features) para decidir o melhor corte.

# random_state=1: Garante que a árvore seja construída da mesma forma em todas as rodadas.

# ccp_alpha=0.0: Parâmetro de "poda" (pruning). Valores maiores que 0 cortam 
# galhos que ajudam pouco, simplificando a árvore para melhorar a generalização.

# min_impurity_decrease=0.0: Um nó só é dividido se a redução do erro 
# for maior ou igual a este valor.

# %% [markdown]
# tuning faz vários testes com o modelo, utilzando parâmetros diferentes, com o objetivo de descobrimos qual é o melhor conjunto de parâmetros para esse algoritmo aplicado nessa base de dados (dt => Decision Tree Regressor )

# %% [markdown]
# ### Tuning model

# %%
from pycaret.regression import tune_model

dt_tuning = tune_model(dt)
# Out:
# <style type="text/css">
# #T_811d1_row10_col0, #T_811d1_row10_col1, #T_811d1_row10_col2, #T_811d1_row10_col3, #T_811d1_row10_col4, #T_811d1_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T
td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_811d1_row6_col0" class="data row6 col0" >1636.9310</td>
#       <td id="T_811d1_row6_col1" class="data row6 col1" >4999002.4521</td>
#       <td id="T_811d1_row6_col2" class="data row6 col2" >2235.8449</td>
#       <td id="T_811d1_row6_col3" class="data row6 col3" >0.8928</td>
#       <td id="T_811d1_row6_col4" class="data row6 col4" >0.1526</td>
#       <td id="T_811d1_row6_col5" class="data row6 col5" >0.1206</td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_811d1_row7_col0" class="data row7 col0" >1716.5772</td>
#       <td id="T_811d1_row7_col1" class="data row7 col1" >5345402.0592</td>
#       <td id="T_811d1_row7_col2" class="data row7 col2" >2312.0126</td>
#       <td id="T_811d1_row7_col3" class="data row7 col3" >0.9264</td>
#       <td id="T_811d1_row7_col4" class="data row7 col4" >0.1560</td>
#       <td id="T_811d1_row7_col5" class="data row7 col5" >0.1207</td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_811d1_row8_col0" class="data row8 col0" >2056.4677</td>
#       <td id="T_811d1_row8_col1" class="data row8 col1" >8648960.8395</td>
#       <td id="T_811d1_row8_col2" class="data row8 col2" >2940.9116</td>
#       <td id="T_811d1_row8_col3" class="data row8 col3" >0.7249</td>
#       <td id="T_811d1_row8_col4" class="data row8 col4" >0.1907</td>
#       <td id="T_811d1_row8_col5" class="data row8 col5" >0.1592</td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_811d1_row9_col0" class="data row9 col0" >1774.0278</td>
#       <td id="T_811d1_row9_col1" class="data row9 col1" >4190689.0324</td>
#       <td id="T_811d1_row9_col2" class="data row9 col2" >2047.1172</td>
#       <td id="T_811d1_row9_col3" class="data row9 col3" >0.8896</td>
#       <td id="T_811d1_row9_col4" class="data row9 col4" >0.1295</td>
#       <td id="T_811d1_row9_col5" class="data row9 col5" >0.1220</td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_811d1_row10_col0" class="data row10 col0" >2648.2902</td>
#       <td id="T_811d1_row10_col1" class="data row10 col1" >17308608.8981</td>
#       <td id="T_811d1_row10_col2" class="data row10 col2" >3797.8654</td>
#       <td id="T_811d1_row10_col3" class="data row10 col3" >0.7368</td>
#       <td id="T_811d1_row10_col4" class="data row10 col4" >0.2168</td>
#       <td id="T_811d1_row10_col5" class="data row10 col5" >0.1748</td>
#     </tr>
#     <tr>
#       <th id="T_811d1_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_811d1_row11_col0" class="data row11 col0" >1043.8905</td>
#       <td id="T_811d1_row11_col1" class="data row11 col1" >15240709.5835</td>
#       <td id="T_811d1_row11_col2" class="data row11 col2" >1698.4778</td>
#       <td id="T_811d1_row11_col3" class="data row11 col3" >0.1690</td>
#       <td id="T_811d1_row11_col4" class="data row11 col4" >0.0592</td>
#       <td id="T_811d1_row11_col5" class="data row11 col5" >0.0469</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# escolheu o mehor parâmetro, pelo dt_tuning, do Decision Tree Regressor, com uma média do R2 que aumentou 0.7368

# %%
x = 0.7368*100/0.7077
print(f'o R2 pelo modelo teve um aumento de {x-100:.2f} %.')
# Out:
# o R2 pelo modelo teve um aumento de 4.11 %.

# %%
dt_tuning
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=13,
#                       max_features='sqrt', min_impurity_decrease=0.0005,
#                       min_samples_leaf=3, min_samples_split=7, random_state=1)

# %%
dt_tuning.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'max_depth': 13,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0005,
#  'min_samples_leaf': 3,
#  'min_samples_split': 7,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': 1,
#  'splitter': 'best'}
