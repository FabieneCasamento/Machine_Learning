# %% [markdown]
# ### SVM – máquIna de vetores suporte - Support Vector Machines
#
# ## 1)
# Para tarefas mais complexas, reconhecimento de caracteres, voz, imagens
# deep learning → redes neurais, mais avançados, do que o SVM
#
# separando as classes, aprende hiperplanos de separação com margem máxima.
#
# Encontrar a melhor reta possível

# %% [markdown]
# ![image.png](attachment:bee29a9c-8931-4c13-92c3-a1a84ede9b77.png)

# %% [markdown]
# ![image.png](attachment:893bffa8-4257-43d2-a7a6-477c53aa6d94.png)

# %% [markdown]
# SV -> vetores de suporte
#
# construção do hiperplano

# %% [markdown]
# ![image.png](attachment:8ee084fd-611b-4d79-bad5-89b0777b05b1.png)

# %% [markdown]
# ## 2) Hiperplanos

# %% [markdown]
# ![image.png](attachment:8d77ae88-7f3c-4554-91ac-729f3fbc821b.png)

# %% [markdown]
# geração dos pontos, convex hull
#
# distância entre as duas estruturas, hiperplano de separação

# %% [markdown]
# ![image.png](attachment:4ce150f6-9b0e-4721-bcdf-062eb49a8e69.png)

# %% [markdown]
# Formula do hiperplanos w * x + b =0 (dot product – multiplicação das matrizes dos dados)

# %% [markdown]
# ![image.png](attachment:a1ce0c21-15e6-491b-9d1a-db83f45e8333.png)

# %% [markdown]
# Classes, vermelha e verde
#
# atributos x1 e x2
#
# Quanto maior a distância maior é o erro. Os dados estão mais longe do meu hiperplano de separação.
#
# SVM mínimo de erro possível: mínima margem.
#
# Mínimo erro.
#
#
# Cálculo do erro
#
# criar uma reta
#
# distância
# ai = 0,7 + ai=0,5
#
# ai_total = 0,12
#
#
# #### c for maior, maior o algoritmo será mais eficiente. Tentar encontrar o hiperplano com o mínimo erro possível.
#
# variável c.
#
#
# valor de c alto, com o hiperplano
#
# c baixo terá mais erros.
#
# ![image.png](attachment:0030b403-06af-468e-b79d-c63d5ab6487b.png)

# %% [markdown]
# # 3) Problemas linearmente separáves e não linearmente separados
#
# único apenas 1 no y=1 e x =1
# V 1 F 0

# %% [markdown]
# ![image.png](attachment:ee5281ae-baed-43f1-a122-e76b64e3336e.png)

# %% [markdown]
# ### SVMs não lineares (kernel trick - truque)
#
# transfoma os dados não lineares para lineares → Kernel trick
#
# ![image.png](attachment:81c3569b-61e8-4e88-9a18-7369eed92cee.png)

# %% [markdown]
# 1 dimensão e 2 classes (R1 e R2)
#
# kernel linear mais simples, eleva 1 dimensão para duas dimensões
#
# -3² -2² 0² 1² 2² 3² 5²
#
# 9 4  0 1 4 9 25
#
# Aumentar a dimencionalidade dos dados

# %% [markdown]
# ![image.png](attachment:e1fa49ea-397d-4a1d-b332-7b25d10f8fe6.png)

# %% [markdown]
# determinar antes sempre o tip de kernel a ser utilizado
#
#
# ![image.png](attachment:75807fe7-c09a-4e43-8147-fc1942d10e43.png)
#
#
# ![image.png](attachment:f1870a38-258f-47e0-957c-09a3258c087d.png)
#
#
# https://scikit-learn.org/stable/modules/generated/sklearn.gaussian_process.kernels.

# %% [markdown]
# Colocar em 3 dimensões

# %% [markdown]
# ![image.png](attachment:0e6864ff-662b-475c-ac91-6f54ad9d0620.png)

# %% [markdown]
# SVM
#
# - Positivo
#
# Não tem muita influencia por ruídos nos dados
#
# classificação e regressão
#
# aprender conceitos não presentes nos dados originais
#
# mais fácil de usar do que redes neurais
#
#
# - Pontos negativos
#
# testar várias combinações de parâmetros
#
# lento
#
# No svm não conseguimos ver as regras, black box

# %% [markdown]
# ### 1) Com o SVM é possível encontrar uma linha de separação entre dados de duas classes, que é chamado de:
#
# "Hiperplano" porque, no SVM, essa é a linha (ou plano) que separa as duas classes de dados de forma ótima, alinhando-se exatamente ao objetivo de encontrar essa fronteira de separação.
#
#
#
# ### 2) O conceito de aprendizado por hiperplano com margem máxima consiste em:
#
# no aprendizado por hiperplano com margem máxima (SVM), quanto maior a distância dos pontos ao hiperplano, melhor a separação entre as classes, aumentando a margem e a robustez do modelo.
#
# quanto maior a distância dos pontos em relação a reta, melhor.
#
# ### 3) O parâmetro custo (c) do SVM representa:
#
# Uma punição por classificação incorreta.
#
# O parâmetro custo (C) no SVM controla a penalidade aplicada quando o modelo classifica um dado de forma incorreta, ajudando a equilibrar a margem e o erro para melhorar a precisão do classificador.
#
#
#
# #### 4) Um problema linear é aquele no qual é possível separar duas classes apenas com uma reta. Por outro lado, um problema não-linear é quando não é possível traçar uma reta para separar os dados. Nesse caso, é possível utilizar as técnicas de kernels do SVM para transformar um problema não linearmente separável em um problema linearmente separável
#
#
# a técnica de kernels no SVM permite transformar dados não linearmente separáveis em um espaço de maior dimensão onde uma reta (hiperplano) pode separar as classes, facilitando a solução do problema de classificação.
