# %% [markdown]
# # 29.2) exercício de atributos

# %%
# from google.colab import drive
# drive.mount('/content/drive')
import os
DRIVE_DIRECTORY = "/home/fabiene/Documentos/Fabiene/UDEMY_ML/Machine_Learning_Udemy/10-Redes_neurais_artificiais/exercicios/novo"

# %% [markdown]
# no linux find -name "cov_types.csv"
#
# ./Documentos/Fabiene/UDEMY_ML/Machine_Learning_Udemy/10-Redes_neurais_artificiais/exercicios/novo/cov_types.csv

# %%
#biblioteca 

import numpy as np
import pandas as pd
import pickle

from sklearn.ensemble import ExtraTreesClassifier, RandomForestClassifier
from sklearn.feature_selection import VarianceThreshold
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %% [markdown]
# ## Seleção de atributos
# ### Base de dados cobertura vegetal
#
# Neste exercício você vai mais uma vez utilizar a base de dados cobertura vegetal.
#
# Carregue o arquivo csv salvo na pasta do Drive. Visualize o DataFrame resultante.

# %%
base = pd.read_csv(os.path.join(DRIVE_DIRECTORY, 'cov_types.csv'))
base.tail(5)
# Out:
#       Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 9995     2917.0    90.0    9.0                             247.0
# 9996     3015.0    38.0    8.0                             361.0
# 9997     3052.0    79.0   19.0                              90.0
# 9998     2958.0    58.0    6.0                             319.0
# 9999     2682.0    91.0   13.0                             162.0
#
#       Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 9995                            25.0                           4095.0
# 9996                            74.0                           4846.0
# 9997                            11.0                           1003.0
# 9998                            19.0                           2468.0
# 9999                            32.0                           1369.0
#
#       Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 9995          235.0           225.0          121.0
# 9996          220.0           223.0          138.0
# 9997          241.0           203.0           85.0
# 9998          225.0           227.0          137.0
# 9999          240.0           219.0          108.0
#
#       Horizontal_Distance_To_Fire_Points  Wilderness_Area  Soil_Type  \
# 9995                              3901.0                0         28
# 9996                              1611.0                0         28
# 9997                              1490.0                2         22
# 9998                              2280.0                0         28
# 9999                              1661.0                2         10
#
#           Cover_Type
# 9995  Lodgepole Pine
# 9996  Lodgepole Pine
# 9997      Spruce/Fir
# 9998  Lodgepole Pine
# 9999  Lodgepole Pine

# %% [markdown]
# # colunas categoricas: Cover_Type

# %% [markdown]
# Desta vez você vai remover as colunas categóricas, pois a variância é mais informativa para atributos numéricos.
#
#
# Primeiro, separe o nome das colunas em uma variável `colunas`, mas lembre-se de remover as 3 últimas colunas (que correspondem às 2 variáveis categóricas, mais a variável alvo).

# %%
print(base.columns)
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points', 'Wilderness_Area', 'Soil_Type',
#        'Cover_Type'],
#       dtype='object')

# %%
columns = base.columns[:-3]
columns
# Out:
# Index(['Elevation', 'Aspect', 'Slope', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Hillshade_9am', 'Hillshade_Noon', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points'],
#       dtype='object')

# %% [markdown]
# Agora crie as variáveis `X` e `y`, no formato de NumPy array, mas não inclua as variáveis categóricas em `X`.

# %%
X = base.iloc[:, :-3].values # previsores 
y = base.iloc[:, -1].values

# %% [markdown]
# Exiba os valores de X.

# %%
X
# Out:
# array([[2767.,   66.,   17., ...,  204.,   96., 2251.],
#        [2724.,  160.,   19., ...,  240.,  127., 2514.],
#        [2360.,   65.,    7., ...,  226.,  134.,  339.],
#        ...,
#        [3052.,   79.,   19., ...,  203.,   85., 1490.],
#        [2958.,   58.,    6., ...,  227.,  137., 2280.],
#        [2682.,   91.,   13., ...,  219.,  108., 1661.]], shape=(10000, 10))

# %%
y # categórico
# Out:
# array(['Lodgepole Pine', 'Lodgepole Pine', 'Ponderosa Pine', ...,
#        'Spruce/Fir', 'Lodgepole Pine', 'Lodgepole Pine'],
#       shape=(10000,), dtype=object)

# %% [markdown]
# # normalizar na escala entre 0 e 1

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[0.4477459 , 0.18333333, 0.30909091, ..., 0.66666667, 0.384     ,
#         0.31482517],
#        [0.42571721, 0.44444444, 0.34545455, ..., 0.90666667, 0.508     ,
#         0.35160839],
#        [0.2392418 , 0.18055556, 0.12727273, ..., 0.81333333, 0.536     ,
#         0.04741259],
#        ...,
#        [0.59375   , 0.21944444, 0.34545455, ..., 0.66      , 0.34      ,
#         0.20839161],
#        [0.54559426, 0.16111111, 0.10909091, ..., 0.82      , 0.548     ,
#         0.31888112],
#        [0.40420082, 0.25277778, 0.23636364, ..., 0.76666667, 0.432     ,
#         0.23230769]], shape=(10000, 10))

# %% [markdown]
# Codifique os dados de `y` utilizando `LabelEncoder`.

# %% [markdown]
# ## codificar os dados de y com o LabelEncoder

# %%
y
# Out:
# array(['Lodgepole Pine', 'Lodgepole Pine', 'Ponderosa Pine', ...,
#        'Spruce/Fir', 'Lodgepole Pine', 'Lodgepole Pine'],
#       shape=(10000,), dtype=object)

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y)
y
# Out:
# array([4, 4, 5, ..., 6, 4, 4], shape=(10000,))

# %%
DRIVE_DIRECTORY2=""

# %%
# salvar o arquivo nesta forma 
with open(os.path.join(DRIVE_DIRECTORY2, "cover_type_num.pkl"), "wb") as f:
    pickle.dump((X, y), f)

# %% [markdown]
# ### Variância
#
# Exiba a variância dos dados preditores. DICA: ao invés de um implementar um loop, você pode usar o método `var` com o parâmetro `axis=0`, que vai calcular a variância nas colunas.

# %%
X.var(axis=0)
# Out:
# array([0.02040914, 0.09559695, 0.01843345, 0.02361915, 0.0068116 ,
#        0.05098971, 0.01885846, 0.01751286, 0.02366312, 0.03431677])

# %%
len(base.columns[:-3]) # X
# Out:
# 10

# %% [markdown]
# Perceba que temos 10 valores, correspondentes às 10 colunas numéricas do dataset.

# %% [markdown]
# Crie um seletor do tipo `VarianceThreshold` utilizando `threshold=0.02`. Exiba o `shape` do resultado.

# %% [markdown]
# remove features com variância baixa, ou seja, que quase não variam e por isso não ajudam o modelo.
#
# remove colunas com variância menor que 0.02.

# %%
selector = VarianceThreshold(threshold=0.02)
X_variance = selector.fit_transform(X)
X_variance.shape
# Out:
# (10000, 6)

# %%
print(f'foram selecionados {X_variance.shape[1]} colunas')
# Out:
# foram selecionados 6 colunas

# %% [markdown]
# Exiba as variâncias armazenadas no seletor.

# %%
selector.variances_
# Out:
# array([0.02040914, 0.09559695, 0.01843345, 0.02361915, 0.0068116 ,
#        0.05098971, 0.01885846, 0.01751286, 0.02366312, 0.03431677])

# %% [markdown]
# Perceba que os resultados são os mesmos que você calculou antes.
#
# Recupere os índices das colunas que foram selecionadas.

# %%
indices = np.where(selector.variances_ > 0.02)
indices
# Out:
# (array([0, 1, 3, 5, 8, 9]),)

# %%
for i in range(X.shape[1]):
   print(f"Atributo {i+1}: {base.columns[i]}")
   print(f"Variância do atributo, ou extração da variância: {X[:,i].var():.2f}")
   #print("Variância escalonada")
   if X[:,i].var() > 0.02:
       # Verde
       print(f"Variância do atributo escalonado ({base.columns[i]}): \033[32m{X[:,i].var():.5f}\033[0m")       
   else:        
       print(f"Variância do atributo escalonado ({base.columns[i]}): {X[:,i].var():.5f}")
   print()

    
# \033[92m → verde
# \033[0m → volta à cor normal
# \033[32m → verde
# Out:
# Atributo 1: Elevation
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Elevation): 0.02041
#
# Atributo 2: Aspect
# Variância do atributo, ou extração da variância: 0.10
# Variância do atributo escalonado (Aspect): 0.09560
#
# Atributo 3: Slope
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Slope): 0.01843
#
# Atributo 4: Horizontal_Distance_To_Hydrology
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Horizontal_Distance_To_Hydrology): 0.02362
#
# Atributo 5: Vertical_Distance_To_Hydrology
# Variância do atributo, ou extração da variância: 0.01
# Variância do atributo escalonado (Vertical_Distance_To_Hydrology): 0.00681
#
# Atributo 6: Horizontal_Distance_To_Roadways
# Variância do atributo, ou extração da variância: 0.05
# Variância do atributo escalonado (Horizontal_Distance_To_Roadways): 0.05099
#
# Atributo 7: Hillshade_9am
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Hillshade_9am): 0.01886
#
# Atributo 8: Hillshade_Noon
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Hillshade_Noon): 0.01751
#
# Atributo 9: Hillshade_3pm
# Variância do atributo, ou extração da variância: 0.02
# Variância do atributo escalonado (Hillshade_3pm): 0.02366
#
# Atributo 10: Horizontal_Distance_To_Fire_Points
# Variância do atributo, ou extração da variância: 0.03
# Variância do atributo escalonado (Horizontal_Distance_To_Fire_Points): 0.03432

# %% [markdown]
# Qual o nome das colunas selecionadas?

# %%
columns[indices]
# Out:
# Index(['Elevation', 'Aspect', 'Horizontal_Distance_To_Hydrology',
#        'Horizontal_Distance_To_Roadways', 'Hillshade_3pm',
#        'Horizontal_Distance_To_Fire_Points'],
#       dtype='object')

# %% [markdown]
# Agora, utilize os dados em `X_variance` e `y` para separar os dados em split de treinamento, e de teste (com `test_size=0.25`).

# %%
X_train, X_test, y_train, y_test = train_test_split(X_variance,
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=0)

# %%
X_train.shape, X_test.shape  # treino 75% e teste 25%
# Out:
# ((7500, 6), (2500, 6))

# %% [markdown]
# Crie uma instância do tipo `RandomForestClassifier`, com os argumentos padrão e `random_state=0`. Treine o algoritmo com os dados de treinamento.

# %%
tree_classifier = RandomForestClassifier(random_state=0)
tree_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
tree_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Faça predições para os dados de teste, e calcule a acurácia.

# %%
y_pred = tree_classifier.predict(X_test) # preditor

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7712

# %%
print(f'Acurácia {accuracy_score(y_test, y_pred)*100:.2f} %')
# Out:
# Acurácia 77.12 %

# %% [markdown]
# Veja que neste caso, o algoritmo ficou um pouco pior que aquele treinado na **Parte 1**. Isso indica que, por mais que tenhamos acentuado os atributos com maior variância, e potencialmente por isso mais poder discriminativo, tanto os atributos de menor variância quanto os atributos categóricos têm influência não desprezível na classificação das árvores.

# %%
# ficou baixo em comparação com outro método => a acurácia ficou maior

#=> M26-Exercicio_Tratamento_de_dados_desbalanceados.ipynb

# %% [markdown]
# ### Extra tree

# %% [markdown]
# Agora crie e treine uma instância do seletor `ExtraTreesClassifier`. Utilize todos os dados, ou seja, as variáveis `X`e `y`, na fase de seleção de atributos.

# %%
selector = ExtraTreesClassifier()
selector.fit(X, y)
# Out:
# ExtraTreesClassifier()

# %%
selector.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Exiba as importâncias determinadas pelo algoritmo.

# %%
selector.feature_importances_
# Out:
# array([0.30522361, 0.06814081, 0.06333626, 0.08039422, 0.0747249 ,
#        0.10671007, 0.06488601, 0.0676884 , 0.06340912, 0.10548661])

# %% [markdown]
# Com auxílio do NumPy, recupere os índices com importância maior que $0.07$.

# %%
indices = np.where(selector.feature_importances_ > 0.07)
indices
# Out:
# (array([0, 3, 4, 5, 9]),)

# %% [markdown]
# Que atributos foram selecionados?

# %%
columns[indices]
# Out:
# Index(['Elevation', 'Horizontal_Distance_To_Hydrology',
#        'Vertical_Distance_To_Hydrology', 'Horizontal_Distance_To_Roadways',
#        'Horizontal_Distance_To_Fire_Points'],
#       dtype='object')

# %% [markdown]
# Filtre os dados em `X` para recuperar somente os índices selecionados. Agora, observe que `indices` é uma tupla contendo um elemento, que é o array com os índices, então nesta construção você deve utilizar `indices[0]` para recuperar os índices dentro da tupla.

# %%
indices[0]
# Out:
# array([0, 3, 4, 5, 9])

# %%
X_tree = X[:, indices[0]]

# %%
X_tree
# Out:
# array([[0.4477459 , 0.15261628, 0.21276596, 0.17181634, 0.31482517],
#        [0.42571721, 0.04360465, 0.1929078 , 0.1949177 , 0.35160839],
#        [0.2392418 , 0.09229651, 0.21702128, 0.19881606, 0.04741259],
#        ...,
#        [0.59375   , 0.06540698, 0.20283688, 0.14481663, 0.20839161],
#        [0.54559426, 0.2318314 , 0.2141844 , 0.35633843, 0.31888112],
#        [0.40420082, 0.11773256, 0.23262411, 0.19766099, 0.23230769]],
#       shape=(10000, 5))

# %% [markdown]
# Mais uma vez, separe os dados `X_tree` e `y` em split de treinamento, e de teste (com `test_size=0.25`).

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tree, 
                                                    y, 
                                                    test_size=0.25, 
                                                    random_state=0)

# %%
X_train.shape, X_test.shape
# Out:
# ((7500, 5), (2500, 5))

# %%
tree_classifier = RandomForestClassifier(random_state=0)
tree_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
tree_classifier.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Faça predições para os dados de teste, e calcule a acurácia.

# %%
y_pred = tree_classifier.predict(X_test) # preditor

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7704

# %%
print(f'Acurácia {accuracy_score(y_test, y_pred)*100:.2f} %')
# Out:
# Acurácia 77.04 %

# %% [markdown]
# Mais uma vez esta seleção se mostrou pior que utilizar todos os dados, ou seja ficou semelhante a seleção baseada em variância.

# %% [markdown]
# Uma das principais diferenças entre os algoritmos Randon Forest e Extra Trees é que o primeiro escolhe uma divisão ideal enquanto o segundo escolhe aleatoriamente.
#
# o algoritmo Random Forest seleciona a melhor divisão para as árvores, enquanto o Extra Trees faz escolhas aleatórias. Isso reflete uma diferença chave entre os dois algoritmos em termos de como eles constroem suas árvores de decisão.
