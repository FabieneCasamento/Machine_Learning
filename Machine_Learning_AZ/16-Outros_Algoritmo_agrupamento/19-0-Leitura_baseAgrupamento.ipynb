# %% [markdown]
# Outro tipo de agrupamento, o hierárquico
#
#
# # Agrupamento hierárquico
#
# ### - É criada uma estrutura em formato de árvore que indica o número de clusters.
#
# usando o método elbow método  para verificar o número ideal de cluster
#
# vamos fazer a verificação do número de cluster por meio de uma árvore de decisão que vamos implementar a vizualização que é chamada de aglomerativa.
#
#
# ### - Abordagem aglomerativa: Cada registro pertence ao seu próprio cluster e pares de clusters são unidos.
#
# cada um dos registros equivalem a um cluster, se nós temos 10 registros, cada um desses 10 registros são considerados um cluster por si só
#
# ### - os resultados podem ser apresentados em um dendrograma.

# %% [markdown]
# ![image.png](attachment:14d526a3-c352-46f0-9ac6-bc55d49420a2.png)

# %% [markdown]
# exemplo salário x idade
#
# vamos considerar uma pequena amostra dos registros, para não usar tantos dados pois nosso endrograma ficará mais confuso.
#
# Isso para entendermos como funciona o algoritmo.
#
# cada um dos registros pertencem a um único cluster
#
#
# #### distância euclidiana , como o algoritmo kaminski aqui também nós vamos precisar fazer o cálculo da distância. O qual próximo um registro está do outro.
#
#
# 5 e 6 clusters mais próximos , distância de 0,5 euclidiana

# %% [markdown]
# ![image.png](attachment:6a5b6294-cfa0-497f-b143-7e13450d859f.png)

# %% [markdown]
# No final junta tudo para ser um único cluster
#
# distância grande

# %% [markdown]
# ###  e Traçar uma reta entre os 2 clusters

# %% [markdown]
# ![image.png](attachment:e361e0f0-25cb-4240-a75d-ae91ebc01a13.png)

# %% [markdown]
# O ideial seria usar 2 clusters.
#
#
# Ideal para identificar quantos clusters usaremos.
#
# pegar a linha que tem a maior distância euclidiana e que não cruze com nehuma outra linha.
#
#
#
# A linha no 0,5 de distância cruza com a linha do eixo x 5 e 6
#
# ideal

# %% [markdown]
# #### Agrupamento com DBSCAN
#
# - Density-Based Spatial Clustering of Applications with Noise.
#
# Densidade com parte espacial
#
# - Baseado em densidade, agrupando os pontos similares no mesmo espaço.
#
# Cálculos de similaridades
#
# - Não é necessário especificar o número de clusters
#
# o modelo busca achar o número de clusters
#
# - em geral apresenta melhores resultados que o k-means
#
# o ideal é sempre testar
#
# - Mais rápido que o k-means
#
#
# - Tenta encontrar os pontos que são separados por uma distância não maior do que um limiar (threshold distance) -> bibliotecas e parâmetro mínimo que vai estar um elemento para ser considerado dentro de um cluster.

# %% [markdown]
# ![image.png](attachment:9b369b95-d004-45d0-b184-2b6474d6d5ae.png)

# %% [markdown]
# ![image.png](attachment:3e567c3c-df8a-400a-9fd9-5fe0aac27ae4.png)

# %% [markdown]
# Vai centralizando bolinha por bolinha, com o raio padrão
#
# raio dentro do registro mais próximo

# %% [markdown]
# ![image.png](attachment:892519e1-a6e2-4032-866e-4c0fa9291527.png)

# %% [markdown]
# ![image.png](attachment:772049d8-9b81-49ff-8f6b-76792a7fcfe9.png)

# %% [markdown]
# ![image.png](attachment:4bff7eaa-aa99-49a6-abb5-10edd0320bdd.png)

# %% [markdown]
# Agora não tem mais registro próximo, mudar para outro grupo.
#
#
#
#
# começar novamente, com outro ponto aleatório

# %% [markdown]
# ![image.png](attachment:e2c0a2d1-8724-4d45-b615-222588d40dec.png)

# %% [markdown]
# repedindo um a um final azul
#
# ![image.png](attachment:426d408e-8ad2-4051-b6da-690f76687a45.png)

# %% [markdown]
# Agora coleta outro ponto aleatório.
#
#
# descobre o número do cluster, com base na formatação dos registros.

# %% [markdown]
# ![image.png](attachment:6616be0f-6c2d-4e1a-9115-8f6db97492c3.png)

# %% [markdown]
# ![image.png](attachment:f788fa5d-03f8-4d05-ae82-c48cd077005b.png)

# %% [markdown]
# Feito a separação dos grupos
#
# ### dependendo da inicialização podemos classificar de modo diferente.
#
#
# ### Precisa fazer muitos testes, para definiciar o melhor parâmetros
#
#
# difícil para encontrar os melhores parâmetros
#
# DBSCAN
#
#
#
# - Encontra padrões não lineares
#
# - Robusto contra outliers
#
# - O resultado pode ser mais consistente que o k-means porque a inicialização dos "centroides" não afeta tanto o algoritmo.
#
# - Dependendo da inicialização, um ponto pode pertencer ao cluster dependendo da ordem
#
# ponto pode ficar em um grupo verde, e inicializando de outra forma o mesmo ponto pode ficar no grupo vermelho, por exemplo.
#
# - Pode ser difícil encontrar um bom valor para o parâmetro da distância
