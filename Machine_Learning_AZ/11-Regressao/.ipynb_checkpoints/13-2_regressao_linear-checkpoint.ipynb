# %% [markdown]
# # Regressão linear - teoria.

# %% [markdown]
# Regressão linear, fazer previsão de números.
#
# Classificação, risco médio, baixo e alto.
#
# x = atributos previsores , previsão é y
#
#
# ![image.png](attachment:a6440f36-8539-4b92-8782-953164ab07b7.png)

# %% [markdown]
# Problema de regressão linear simples;
#
# previsão do custo (y), x = idade
#
# equação da reta

# %% [markdown]
# ![image.png](attachment:142445d3-5d1a-41f4-a12c-17e0abb90daf.png)

# %% [markdown]
# Distância do registro  da previsão até a linha da regressão => residual. Valor original até o valor da previsão, ou seja a distância, que é o erro residual.
#
# Erros e distância residual.

# %% [markdown]
# ![image.png](attachment:df0ad716-b300-4bc4-9805-8bf3a3fde486.png)

# %% [markdown]
# Cálculo do erro.
#
# MSE, quanto menor melhor.
#
# A ideia do algoritmo é minimizar o MSE, mais próximo o modelo tende a acertar.
#
# ![image.png](attachment:beb4b334-b549-45de-a7d3-9fd650fbf7e6.png)

# %% [markdown]
# Ajustar os dados do bo e b1, para minimizar o erro MSE.
#
#
# gradient descent -> aplicado também em regressões logisticas e redes neurais
#
#
# ![image.png](attachment:90beaf90-be16-4997-b409-3ede4bfd641b.png)
#
#
#
# ### Descida do gradiente, mínimo total, e mínimo local.
#
#
# min C custo
#
# conceito da taxa de aprendizagem.
#
#
# ![image.png](attachment:3524136b-753b-4601-ba36-c04ab2d95ca1.png)

# %% [markdown]
# ![image.png](attachment:67b257d4-53ce-4784-b917-90713d3a0e45.png)
