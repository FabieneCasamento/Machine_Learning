# %% [markdown]
# Rastreamento de objetos
#
# - Rastreamento de objetos) Mais rápidos que os algoritmos de detecção;
#
# - Algoritmo de detecção sempre "começa do zero"
#
# - Rastreamento usa a informação anterior
#
# Rastreamento, para detectar oclusões
#
# ## OpenCV
#
# Algoritmo CSRT (Discriminative Correlation Filter With Channel and Spatial Reliability)
#
# melhor desempenho, pois consegue rastrear bem o objeto.
#
#
# Passoas a seguir:

# %% [markdown]
# 1) Patch – correlação, para indicar dados de treinamento, dados da imagem para ser rastreada.
#
#
# 2) HOG usa histogramadas para detectar objetos.
#
# Concorrente ao cascade, o HOG é melhor que o cascade.
#
# 3) Teste aleatório de Markov
#
# previsão de probabilidade.
#
# 4) patch, mapa de confiabilidade
#
# 5) imagem realmente detectada.
#
# Melhor desempenho.

# %% [markdown]
# ![image.png](attachment:ca8a0936-d3c6-4563-bfae-c17f4418da42.png)
