# %% [markdown]
# ### Ambiente do Anaconda

# %%
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %% [markdown]
# ## 34.1) Operações matemáticas

# %%
a = 5
b = 3
print(a, b)
# Out:
# 5 3

# %%
a + b
# Out:
# 8

# %%
print(f'A soma de {a} com {b} é', a + b)
# Out:
# A soma de 5 com 3 é 8

# %%
print(f'A subtração de {a} com {b} é', a - b)
# Out:
# A subtração de 5 com 3 é 2

# %%
print(f'A divisão de {a} por {b} é', a / b)
# Out:
# A divisão de 5 por 3 é 1.6666666666666667

# %%
print(f'A multiplicação de {a} com {b} é', a * b)
# Out:
# A multiplicação de 5 com 3 é 15

# %%
print(f'O resto da divisão de 10 por 3 é', 10 % 3)
# Out:
# O resto da divisão de 10 por 3 é 1

# %%
print(f'O resto da divisão de 10 por 2 é', 10 % 2)
# Out:
# O resto da divisão de 10 por 2 é 0

# %%
print(f'A divisão de 10 por 3 é', 10 / 3)
# Out:
# A divisão de 10 por 3 é 3.3333333333333335

# %%
print(f'A divisão de 10 por 2 é', 10 / 2)
# Out:
# A divisão de 10 por 2 é 5.0

# %% [markdown]
# ### elevado

# %%
print('5 elevado a 3 é', 5**3)
# Out:
# 5 elevado a 3 é 125

# %%
5 * 5 * 5
# Out:
# 125

# %%
print('5 elevado a 4 é', 5**4)
# Out:
# 5 elevado a 4 é 625

# %%
5 * 5 * 5 * 5
# Out:
# 625

# %% [markdown]
# ### Raiz quadrado de 81

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %% [markdown]
# ## Arredondamento

# %%
casos_doenca = 134
numero_habitantes = 34432
casos_por_habitante = casos_doenca / numero_habitantes
print(casos_por_habitante)
# Out:
# 0.003891728624535316

# %%
round(casos_por_habitante, 6) # número, número depois da vírgula
# Out:
# 0.003892

# %%
round(casos_por_habitante, 2)
# Out:
# 0.0

# %%
round(casos_por_habitante, 5)
# Out:
# 0.00389

# %%
print('O número de casos por habitante é de', round(casos_por_habitante, 4))
# Out:
# O número de casos por habitante é de 0.0039
