# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
#  # Manipulação de arquivos
#
#  [texto do link]

# %%
# leitura simples
with open('frase_aula23.txt') as tex:
  for linha in tex:
    print(linha)
# Out:
# Olá
#
# Estou aprendendo
#
# a linguagem Python
#
# E estou gostando muito

# %%
with open('frase_aula23.txt', 'r') as tex:
  for linha in tex:
    print(linha)
# Out:
# Olá
#
# Estou aprendendo
#
# a linguagem Python
#
# E estou gostando muito

# %% [markdown]
# ### armazenar os dados txt em uma lista

# %%
with open('frase_aula23.txt') as tex:
  r = tex.readlines() # colocar os dados ou as linhas todas no r

# %%
r
# Out:
# ['Olá\n',
#  'Estou aprendendo\n',
#  'a linguagem Python\n',
#  'E estou gostando muito\n']

# %%
# novo arquivo de texto, escrever w
with open('novo_aula23.txt', 'w') as texto:
  texto.write('Olá a todos')

# %%
texto
# Out:
# <_io.TextIOWrapper name='novo_aula23.txt' mode='w' encoding='UTF-8'>

# %%
print(texto)
# Out:
# <_io.TextIOWrapper name='novo_aula23.txt' mode='w' encoding='UTF-8'>

# %%
print(texto.read)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x7f78a8285d80>

# %%
# leitura checar corretamente
with open('novo_aula23.txt', 'r') as tex:
  for linha in tex:
    print(linha)
# Out:
# Olá a todos
