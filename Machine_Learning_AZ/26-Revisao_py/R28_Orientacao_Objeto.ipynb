# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
# EXERCÍCIO
# Olá,
#
# Para revisar o conteúdo prático visto até agora, você agora pode resolver um exercício. Logo em seguida você pode acessar a aula em vídeo com a solução
#
# Crie uma classe chamada aluno com os seguintes atributos:
# - Nome
# - Nota 1
# - Nota 2
# - Crie um construtor para a classe (__init__)
#
#
#
# Crie as seguintes funções (métodos):
# - Calcula média, retornando a média aritmética entre as notas
# - Mostra dados, que somente imprime o valor de todos os atributos
# - Resultado, que verifica se o aluno está aprovado ou reprovado (se a média for maior ou igual a 6.0, o aluno está aprovado)
#
#
#
# Crie dois objetos (aluno1 e aluno2) e teste as funções
#
# Bom trabalho,

# %% [markdown]
# # Exercício 1
#
# Crie uma classe chamada aluno com os seguintes atributos:
#
# - Nome
# - Nota 1
# - Nota 2
# - Crie um construtor para a classe (__init__)
#
# Crie as seguintes funções (métodos):
#
# - Calcula média, retornando a média aritmética entre as notas
# - Mostra dados, que somente imprime o valor de todos os atributos
# - Resultado, que verifica se o aluno está aprovado ou reprovado (se a média for maior ou igual a 6.0, o aluno está aprovado)
#
# Crie dois objetos (aluno1 e aluno2) e teste as funções

# %%
class Aluno:
  def __init__(self, nome, nota1, nota2):
    # armazenar os atributos   
    # self padrão obrigatório  
    self.nome = nome
    self.nota1 = nota1
    self.nota2 = nota2
    # média iniciada como float, depois será atualizado  
    self.media = 0.0
   
  def calcula_media(self):
    self.media = (self.nota1 + self.nota2) / 2
    return self.media

  def mostra_dados(self):
    print('Nome: ', self.nome)
    print('Nota 1:', self.nota1)
    print('Nota 2:', self.nota2)
    print('Média:', self.media)
  
  def resultado(self):
    if self.media >= 6.0:
      print('Aprovado')
    else:
      print('De Recuperação para fazer outra prova ou Reprovado se não fizer a outra prova')

# %%
aluno1 = Aluno('Pedro', 7.0, 9.0)
media = aluno1.calcula_media()
print(media)
# Out:
# 8.0

# %%
aluno1.mostra_dados()
# Out:
# Nome:  Pedro
# Nota 1: 7.0
# Nota 2: 9.0
# Média: 8.0

# %%
aluno1.resultado()
# Out:
# Aprovado

# %%
aluno2 = Aluno('João', 7.0, 2.0)
media = aluno2.calcula_media()
aluno2.mostra_dados()
aluno2.resultado()
# Out:
# Nome:  João
# Nota 1: 7.0
# Nota 2: 2.0
# Média: 4.5
# De Recuperação para fazer outra prova ou Reprovado se não fizer a outra prova

# %%
class Aluno:
    def __init__(self, nome, nota1, nota2):
        # armazenar os atributos   
        # self padrão obrigatório  
        self.nome = nome
        self.nota1 = nota1
        self.nota2 = nota2
        # média iniciada como float, depois será atualizado  
        self.media = 0.0
   
    def calcula_media(self):
       self.media = (self.nota1 + self.nota2) / 2
       print(self.media) 
       return self.media

    def mostra_dados(self):
        print(f'--- Dados do Aluno ---')
        print(f'Nome: {self.nome} | Nota 1: {self.nota1} | Nota 2: {self.nota2}')
        print(f'Média Calculada: {self.media}')

    def veredito(self):
        if self.media >= 6.0:
            print('Resultado: Aprovado! 🎉')
        else:
            print('Resultado: Reprovado ou Recuperação. 📚')

    
    def main(self): # basta os outros dados estar na função __init__() ok, só colocar self no main
      print(f'Iniciando processamento de: {self.nome}...')
      print('entrada dos dados')
      print('cálculo da média do aluno')
      self.calcula_media()
      print('dados completos da nota do aluno')        
      self.mostra_dados()
      print('resultado final do aluno')
      self.veredito()
      print('----------------------\n')

# %%
aluno3 = Aluno('Paula', 7.0, 9.0)
print(aluno3)
aluno3.main() # Um único comando faz tudo!
# Out:
# <__main__.Aluno object at 0x7490fa6ba250>
# Iniciando processamento de: Paula...
# entrada dos dados
# cálculo da média do aluno
# 8.0
# dados completos da nota do aluno
# --- Dados do Aluno ---
# Nome: Paula | Nota 1: 7.0 | Nota 2: 9.0
# Média Calculada: 8.0
# resultado final do aluno
# Resultado: Aprovado! 🎉
# ----------------------
