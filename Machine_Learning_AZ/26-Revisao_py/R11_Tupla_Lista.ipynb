# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
# ## 35.2) # Coleções

# %%
# humano, cachorro e gato, na forma científica
# 3 valores na tupla

tupla = ('Homo sapiens', 'Canis familiaris', 'Felis catus')

# %%
tupla
# Out:
# ('Homo sapiens', 'Canis familiaris', 'Felis catus')

# %%
tupla[0]
# Out:
# 'Homo sapiens'

# %%
tupla[1]
# Out:
# 'Canis familiaris'

# %%
tupla.index('Canis familiaris') # buscando o index
# Out:
# 1

# %%
for elemento in tupla:
  print(elemento)
# Out:
# Homo sapiens
# Canis familiaris
# Felis catus

# %% [markdown]
# ## Listas

# %%
l1 = ['Homo sapiens', 'Canis familiaris', 'Felis catus']

# animal anfíbio, segundo indica um panda
l2 = ['Xenopus laevis', 'Ailuropoda melanoleuca']

# %%
# concatenar as duas listas

l3 = l1 + l2
print(l3)
# Out:
# ['Homo sapiens', 'Canis familiaris', 'Felis catus', 'Xenopus laevis', 'Ailuropoda melanoleuca']

# %%
l2
# Out:
# ['Xenopus laevis', 'Ailuropoda melanoleuca']

# %%
# multiplicar o texto, duplicou
l2_2 = l2 * 2
print(l2_2)
# Out:
# ['Xenopus laevis', 'Ailuropoda melanoleuca', 'Xenopus laevis', 'Ailuropoda melanoleuca']

# %%
# multiplicar o texto, triplicou
l2_2 = l2 * 3
print(l2_2)
# Out:
# ['Xenopus laevis', 'Ailuropoda melanoleuca', 'Xenopus laevis', 'Ailuropoda melanoleuca', 'Xenopus laevis', 'Ailuropoda melanoleuca']

# %%
l1[0]
# Out:
# 'Homo sapiens'

# %%
l1
# Out:
# ['Homo sapiens', 'Canis familiaris', 'Felis catus']

# %%
# Humano e o cão
l1[0:2]
# Out:
# ['Homo sapiens', 'Canis familiaris']

# %%
# entrada de novos dados
l1.append('Gorila gorila')
print(l1)
# Out:
# ['Homo sapiens', 'Canis familiaris', 'Felis catus', 'Gorila gorila']

# %%
l1.remove('Felis catus') # remover o gato
print(l1)
# Out:
# ['Homo sapiens', 'Canis familiaris', 'Gorila gorila']

# %%
# apagar a lista inteira
del(l1)

# %%
# if isinstance(l1, pd.DataFrame):
#     print("✅ 'leitura' é um DataFrame válido.")
# else:
#     print("❌ Objeto não é um DataFrame.")

# %%
if 'l2' in locals():
    print("A variável existe na memória. ✅")
else:
    print("A variável não foi criada ainda. ❌")
# Out:
# A variável existe na memória. ✅

# %%
if 'l1' in locals():
    print("A variável existe na memória. ✅")
else:
    print("A variável não foi criada ainda. ❌")
# Out:
# A variável não foi criada ainda. ❌

# %%
# if not l2.empty:
#     print(f"O DataFrame tem {leitura.shape[0]} linhas.")
# else:
#     print("O DataFrame está vazio!")

# %%
# percorrer a lista
for item in l2_2:
  print(item)
# Out:
# Xenopus laevis
# Ailuropoda melanoleuca
# Xenopus laevis
# Ailuropoda melanoleuca
# Xenopus laevis
# Ailuropoda melanoleuca
