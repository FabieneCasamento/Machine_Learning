# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %% [markdown]
# #  34.5) Operador condicional

# %%
5 > 3
# Out:
# True

# %%
if 5 > 3:
  print('5 é maior que 3')
print('final')
# Out:
# 5 é maior que 3
# final

# %%
# comentário, comando rápido 
# ctrl + :

# %%
if 5 > 4:
  print('5 é maior')
else:
  print('5 não é maior')
# Out:
# 5 é maior

# %%
if 5 > 14:
  print('5 é maior')
else:
  print('5 não é maior')
# Out:
# 5 não é maior

# %%
n = 9
if n == 4:
  print('n é igual a 4')
else:
  if n == 3:
    print('n é igual a 3')
  else:
    print('n não é igual a 4 nem 3')
# Out:
# n não é igual a 4 nem 3

# %%
n = 4
if n == 4:
  print('n é igual a 4')
else:
  if n == 3:
    print('n é igual a 3')
  else:
    print('n não é igual a 4 nem 3')
# Out:
# n é igual a 4

# %%
x = 1
y = 5
# x maior que 1 e o resto da divisão por 2 do y for igual a 0, número par
if (x > 1) or (y % 2 == 0):
  print('x é maior que 1 ou y é par')
else:
  print('Uma ou nenhuma das condições foram satisfeitas')
# Out:
# Uma ou nenhuma das condições foram satisfeitas

# %%
x = 2
y = 5
# x maior que 1 e o resto da divisão por 2 do y for igual a 0, número par
if (x > 1) or (y % 2 == 0):
  print('x é maior que 1 ou y é par')
else:
  print('Uma ou nenhuma das condições foram satisfeitas')
# Out:
# x é maior que 1 ou y é par

# %%
x = 1
y = 10
# x maior que 1 e o resto da divisão por 2 do y for igual a 0, número par
if (x > 1) and (y % 2 == 0):
  print('x é maior que 1 e y é par')
else:
  print('Uma ou nenhuma das condições foram satisfeitas')
# Out:
# Uma ou nenhuma das condições foram satisfeitas

# %%
x = 2
y = 10
# x maior que 1 e o resto da divisão por 2 do y for igual a 0, número par
if (x > 1) and (y % 2 == 0):
  print('x é maior que 1 e y é par')
else:
  print('Uma ou nenhuma das condições foram satisfeitas')
# Out:
# x é maior que 1 e y é par
