# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
# Olá,
#
# Para revisar o conteúdo prático visto até agora, você pode resolver o exercício abaixo. Logo em seguida você pode acessar a aula em vídeo com a solução
#
# Crie um arquivo .py com duas funções
# - Função para ler um string (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
# - Função para ler um número float (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
#
#
#
# Importar o arquivo criado no Google Colab e testar as funções
#
# Bom trabalho,

# %% [markdown]
# # Exercício 1
#
# Crie um arquivo .py com duas funções
# - Função para ler um string (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
# - Função para ler um número float (recebe como parâmetro uma mensagem e retorna o que o usuário digitou)
#
# Importar o arquivo criado no Google Colab e testar as funções

# %%
# leitura_20.py


# def ler_string(mensagem):
#     return input(mensagem)
    
# def ler_float(mensagem):
#     return float(input(mensagem))

# %%
import leitura_20 as lt

# %%
texto = lt.ler_string('Digite o seu nome: ')
print(texto)
# Out:
# Digite o seu nome:  nome
# nome

# %%
carro = lt.ler_string('Digite o nome do seu carro: ')
print(carro)
# Out:
# Digite o nome do seu carro:  gol
# gol

# %%
numero = lt.ler_float('Digite o valor 1: ')
print(numero)
# Out:
# Digite o valor 1:  2
# 2.0

# %%
numero2 = lt.ler_float('Digite o valor 2: ')
print(numero2)
# Out:
# Digite o valor 2:  5
# 5.0

# %%
from leitura_20 import ler_float

# %%
# from pasta . nome do arquivo import nome da função

# %%
numero3 = ler_float('Digite o valor 3: ')
print(numero3)
# Out:
# Digite o valor 3:  5
# 5.0
