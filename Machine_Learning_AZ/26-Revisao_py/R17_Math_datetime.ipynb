# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
# # 36.0) # Módulos úteis

# %% [markdown]
# ## Biblioteca math
#
# https://docs.python.org/3/library/math.html

# %%
import math

# %%
# raiz quadrada
math.sqrt(9)
# Out:
# 3.0

# %%
# seno
math.sin(45)
# Out:
# 0.8509035245341184

# %%
# cosseno
math.cos(45)
# Out:
# 0.5253219888177297

# %%
#math.log(x[, base])

#With one argument, return the natural logarithm of x (to base e).

# %%
math.log(1000, 10) # log da base 10
# Out:
# 2.9999999999999996

# %%
# log da base 2
math.log(32, 2)
# Out:
# 5.0

# %%
# sem digitar a base, ele fica log na base de euler
math.log(1000)
# Out:
# 6.907755278982137

# %%
# número de euler math.e
math.e # não é uma função e sim constante
# Out:
# 2.718281828459045

# %%
math.log(1000, math.e)
# Out:
# 6.907755278982137

# %%
# valor de pi
math.pi
# Out:
# 3.141592653589793

# %%
#math.tan(x)
#Return the tangent of x radians.

# %%
math.tan(45)
# Out:
# 1.6197751905438615

# %%
#math.atan(x)
#Return the arc tangent of x, in radians. The result is between -pi/2 and pi/2.

# %%
math.atan(45)
# Out:
# 1.5485777614681775

# %% [markdown]
# ## Biblioteca datetime
#
# https://docs.python.org/3/library/datetime.html

# %%
# importando biblioteca
import datetime

# %%
#opções que existem
dir(datetime)
# Out:
# ['MAXYEAR',
#  'MINYEAR',
#  'UTC',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'date',
#  'datetime',
#  'datetime_CAPI',
#  'sys',
#  'time',
#  'timedelta',
#  'timezone',
#  'tzinfo']

# %%
# data de hoje
datetime.date.today()
# Out:
# datetime.date(2026, 2, 3)

# %%
print(datetime.date.today())
# Out:
# 2026-02-03

# %%
# saber a data mais a hora
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 2, 3, 13, 2, 43, 474876)

# %%
print(datetime.datetime.now()) # se fosse no servidor do google seria em UTC (tirar -3)
# Out:
# 2026-02-03 13:03:38.883115

# %%
# criar a data na mão
data = datetime.date(2020, 7, 10)

# %%
data
# Out:
# datetime.date(2020, 7, 10)

# %%
print(data)
# Out:
# 2020-07-10

# %%
# extrair os dados não mão
data.day
# Out:
# 10

# %%
data.month # mês
# Out:
# 7

# %%
data.year # ano
# Out:
# 2020

# %%
horario = datetime.datetime(2020, 7, 10, 7, 30, 0)

# %%
print(horario)
# Out:
# 2020-07-10 07:30:00

# %%
horario
# Out:
# datetime.datetime(2020, 7, 10, 7, 30)

# %%
horario.hour # horário
# Out:
# 7

# %%
horario.minute # minuto
# Out:
# 30

# %%
horario.second # segundos
# Out:
# 0
