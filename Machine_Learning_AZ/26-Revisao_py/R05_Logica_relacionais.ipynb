# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %% [markdown]
# #### 34.4)  Operadores lógicos e relacionais

# %% [markdown]
# ## Operadores lógicos

# %%
a = True
b = False

# %%
print(a, b)
# Out:
# True False

# %%
a and b
# Out:
# False

# %%
a & b
# Out:
# False

# %%
c = False
d = True

# %%
b & c
# Out:
# False

# %%
a & d
# Out:
# True

# %%
c = a and b
print("'A' e 'B' são iguais é", c)
# Out:
# 'A' e 'B' são iguais é False

# %%
# um ou outro é true, então é true
a or b
# Out:
# True

# %%
# outra maneira de dizer se é verdadeiro ou falso
a | b
# Out:
# True

# %%
# bool
d = a or b
print("'A' ou 'B' é igual a", d)
# Out:
# 'A' ou 'B' é igual a True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# ## Operadores relacionais

# %%
5 > 3
# Out:
# True

# %%
5 < 3
# Out:
# False

# %%
5 >= 3
# Out:
# True

# %%
5 >= 5
# Out:
# True

# %%
5 == 3 # igual
# Out:
# False

# %%
5 <= 3
# Out:
# False

# %%
5 != 3 # diferente
# Out:
# True
