# %%
# ambiente anaconda
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
# versão do python
print(sys.version)
# Out:
# 3.11.9 (main, Apr 19 2024, 16:48:06) [GCC 11.2.0]

# %% [markdown]
# EXERCÍCIO
# Olá,
#
# Para revisar o conteúdo prático da aula passada, agora você pode implementar o exercício abaixo. Logo em seguida você pode acessar a aula em vídeo com a solução
#
# Considerando o dicionário com o nome dos alunos e suas respectivas notas abaixo, crie uma estrutura de repetição para percorrer cada elemento do dicionário para gravar cada aluno em um novo arquivo de texto
# - Cada aluno deve ocupar uma linha do novo arquivo de texto
# - O formato deve ser: nome,nota (Pedro,8.0)
# - Após a criação do arquivo de texto, faça a leitura do arquivo e mostre todos os alunos
#
# alunos = {'Pedro': 8.0, 'Maria': 10.0, 'Amilton': 7.5}
# Bom trabalho,

# %% [markdown]
# # Exercício
#
# Considerando o dicionário com o nome dos alunos e suas respectivas notas, crie uma estrutura de repetição para percorrer cada elemento do dicionário para gravar cada aluno em um novo arquivo de texto
# - Cada aluno deve ocupar uma linha do novo arquivo de texto
# - O formato deve ser: nome,nota (Pedro,8.0)
# - Após a criação do arquivo de texto, faça a leitura do arquivo e mostre todos os alunos

# %%
# percorrer os alunos e fazer a gravação em txt. Ou seja, exportação na repetição

# %%
alunos = {'Pedro': 8.0, 'Maria': 10.0, 'Amilton': 7.5}
alunos
# Out:
# {'Pedro': 8.0, 'Maria': 10.0, 'Amilton': 7.5}

# %%
with open('alunos_aula24.txt', 'w') as arquivo:
  for aluno, nota in alunos.items():
    arquivo.write(f'{aluno},{nota}\n') # \n pular linha

# %%
with open('alunos_aula24.txt', 'r') as arquivo:
  for linha in arquivo:
    print(linha)
# Out:
# Pedro,8.0
#
# Maria,10.0
#
# Amilton,7.5
