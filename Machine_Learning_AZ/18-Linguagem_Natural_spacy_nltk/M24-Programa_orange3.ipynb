# %% [markdown]
# ## 24.6) Base de dados carregados do orange

# %% [markdown]
# ### no terminal do python:
#
# criar um ambiente orange3
#
# => conda create -n orange3 python=3.10
#
# => conda activate orange3
#
# => conda install -c conda-forge orange3
#
# => orange-canvas –clear-widget-settings
#
# ### para instalar as bibliotecas
#
# Abra o Orange Canvas
#     • Vá em:
# #### Options → Add-ons...
#     • Na janela que abrir, procure e marque:
# #### ✅ Orange3 Text
#     • Clique em OK / Apply

# %% [markdown]
# ![image.png](attachment:f0ccf9b6-a268-4f39-8df7-fb30cb14650a.png)

# %% [markdown]
# Feito por mim, coloco corpus e corpus view, depois seleciono o tema
#
# eleições 2016

# %% [markdown]
# Seleciono o grim tales

# %% [markdown]
# ![image.png](attachment:abc96dd0-2afc-4630-8f0e-9aba33b2cfa2.png)

# %% [markdown]
# Reload
#
# busco a palavra family no corpus views

# %% [markdown]
# ![image.png](attachment:c2dc3095-19b3-4d85-97ba-3e2954efabe5.png)

# %% [markdown]
# Fazer a geração das palavras mais frequentes

# %% [markdown]
# ![image.png](attachment:e8403765-b52f-467a-889c-b828bb8120ae.png)

# %% [markdown]
# Agora vamos no word cloud

# %% [markdown]
# ![image.png](attachment:16c5a400-fd03-47e7-9773-054dff6902f2.png)

# %% [markdown]
# ## Colocado a quantidade de palavras, clique 2 vezes no icone word cloud

# %% [markdown]
# ![image.png](attachment:2bf14d51-0a2f-460b-a2b4-7fce6034c6a8.png)

# %% [markdown]
# Aparece muita preposição, tem que tirar o stop word
#
# fazer o pré-processamento do texto

# %% [markdown]
# ![image.png](attachment:32c91075-8536-4a48-8bbc-44472123c6bb.png)

# %% [markdown]
# lowercase - letras minusculas
#
# remove accents - tira acentos
#
# parse html- trata dados em html
#
# remove urls- remove urls
#
# filtragem stopwords

# %% [markdown]
# ![image.png](attachment:11dd21f8-c665-4ff7-9dcf-e6f03dda8620.png)

# %% [markdown]
# Feito o preprocessamento, colocamos novamente o world cloud para mostrar as palavras mais digitadas.

# %% [markdown]
# ![image.png](attachment:9d5b5f53-cba8-469c-8b6d-4e27eee16c71.png)

# %% [markdown]
# Fácil de visualizar o que o texto está falando.

# %% [markdown]
# ![image.png](attachment:b5d4f33a-95c8-4e5d-ab34-65d94be8f40b.png)

# %% [markdown]
# Podemos retirar outras palavras, como oh, e criar pela pastinha, no preprocess text.
