# %%
#$conda env list
# conda environments:

#
#base                  *  /home/fabiene/anaconda3
#Maq2                     /home/fabiene/anaconda3/envs/Maq2
#RBA_est                  /home/fabiene/anaconda3/envs/RBA_est
#Robyn                    /home/fabiene/anaconda3/envs/Robyn
#Udemy                    /home/fabiene/anaconda3/envs/Udemy
#YouTube                  /home/fabiene/anaconda3/envs/YouTube
#pycaret-env              /home/fabiene/anaconda3/envs/pycaret-env

#$ conda activate YouTube

# %% [markdown]
# Arquivo pesquisa
#
# https://www.kaggle.com/datasets/toramky/automobile-dataset?resource=download

# %% [markdown]
# https://medium.com/@jair.oliveira1204/an%C3%A1lise-explorat%C3%B3ria-de-dados-com-pandas-profiling-8c2edeeb6958

# %% [markdown]
# características de automóveis.
#
#
# Profiling é ideal antes de fazermos qualquer tratativa dos dados, pois, assim teremos uma visão interresante e extrair insights importantes para uma análise mais específica.

# %%
# Import das bibliotecas
import pandas as pd
import numpy as np
# Carregando os dados
data = pd.read_csv('Automobile_data.csv')
data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# https://docs.profiling.ydata.ai/latest/

# %%
#!pip install pandas-profiling
#!pip install numba==0.55.2
#!pip uninstall pandas-profiling
#!pip install pandas-profiling
#pip install numba

# correto o programa atualizado
#!pip install ydata-profiling

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    data,
    title='Automobile data',
    html={'style': {'full_width': True}},
    sort=None  # CORRETO: sem aspas
)

profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling vv4.16.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-06-02 15:14:17.054097&quot;&gt;&lt;title&gt;Automobile data&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
# antigo
#from pandas_profiling import ProfileReport

#profile = ProfileReport(data, title='Automobile data',
                 html={'style': {'full_width': True}}, sort="None")
#profile
# Out:
#   Cell In[11], line 5
#     html={'style': {'full_width': True}}, sort="None")
#     ^
# IndentationError: unexpected indent

# %%
# relatório criado
profile.to_file("relatorio.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
