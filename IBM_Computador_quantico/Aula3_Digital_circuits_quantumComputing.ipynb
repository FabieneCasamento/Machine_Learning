# %% [markdown]
# ## Boolean Logic & Digital Circuits | Quantum Computing using Python
#
# https://www.youtube.com/watch?v=alXbumuFO2M&list=PLhI5X1mNN8giEspGNb39R1d7ik6RlSI7l&index=5

# %%
# ambiente salvo

import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/pycaret-env/bin/python

# %%
import sys # versão do python
print(sys.version)
# Out:
# 3.11.11 (main, Dec 11 2024, 16:28:39) [GCC 11.2.0]

# %% [markdown]
# ![image.png](attachment:3cfede21-0016-4f01-b9a0-7d2b9ccc613a.png)

# %% [markdown]
# O $P \lor Q$ funciona como uma escolha aberta. Ele só é falso se os dois forem falsos. Se pelo menos um for verdade, tudo é verdade.

# %% [markdown]
# P Q P∨Q (OU)
#
# V V V
#
# V F V
#
# F V V
#
# F F F

# %% [markdown]
# $P \land Q$ só é verdadeiro se tanto P quanto Q forem verdadeiros.
#
#
# P Q P∧Q (E)
#
# V V V
#
# V F F
#
# F V F
#
# F F F

# %% [markdown]
# ![image.png](attachment:2c683220-b823-44d4-8f64-0679dcffcd98.png)

# %% [markdown]
# ![image.png](attachment:2acdbd05-6acb-44fb-bb48-e480b54b10f1.png)

# %% [markdown]
# ![image.png](attachment:93928ce2-f544-48ad-92ce-244459a851a3.png)

# %% [markdown]
# https://learnquantum.io/chapters/01_classical_computing/01_01_bits_and_circuits.html#boolean-logic
#
#
# 2. Boolean Logic

# %% [markdown]
# acima 2 bit
#
#
# abaixo 3 bit
#
# ![image.png](attachment:a4f834e5-c53a-4c47-b7fe-ef7edee3249a.png)

# %%
0 & 0
# Out:
# 0

# %%
1 & 0
# Out:
# 0

# %%
0 & 1
# Out:
# 0

# %%
1 & 1 # and operation
# Out:
# 1

# %% [markdown]
# https://learnquantum.io/chapters/01_classical_computing/01_01_bits_and_circuits.html#digital-circuits
#
# ![image.png](attachment:512aa82f-c047-4087-8b1f-2e1010fd76ef.png)

# %%
# quando um é verdadeiro colocar 
# and operation
1010 & 1111
# Out:
# 82

# %% [markdown]
# diferente número, temos que colocar o 0b antes, para indicar o binário

# %%
# quando um é verdadeiro colocar 
# and operation
0b1010 & 0b1111
# Out:
# 10

# %% [markdown]
# decimal performance

# %%
# quando um é verdadeiro colocar 
# and operation
bin(0b1010 & 0b1111)
# Out:
# '0b1010'

# %%
# quando um é verdadeiro colocar 
# OR operation
bin(0b1010 | 0b1111)
# Out:
# '0b1111'

# %% [markdown]
# teste

# %%
# quando um é verdadeiro colocar 
# and operation
print(bin(0b1111 & 0b1111))

# quando um é verdadeiro colocar 
# and operation
bin(0b1100 & 0b1100)
# Out:
# 0b1111
# '0b1100'

# %%
# XOR operation
bin(0b1010 ^ 0b1111)
# Out:
# '0b101'

# %%
# quando um é verdadeiro colocar 
# OR operation
bin(0b1010 | 0b1110)
# Out:
# '0b1110'

# %%
# XOR operation
bin(0b1010 ^ 0b1110)
# Out:
# '0b100'

# %% [markdown]
# XOR (Ou Exclusivo) entre dois números binários e, em seguida, converte o resultado de volta para uma string binária

# %% [markdown]
# A regra do XOR é simples: o resultado é 1 se os bits forem diferentes e 0 se forem iguais.
#
# Vamos alinhar os bits dos seus números:
#
# 1 0 1 0 (Decimal 10)
#
# 1 1 1 0 (Decimal 14)
#
# 0 1 0 0 ← Resultado

# %%
print('binário: ','0b1010')
x1  = int('0b1010',2)
print('inteiro: ',x1)
# Out:
# binário:  0b1010
# inteiro:  10

# %%
print('binário: ','0b1110')
x2  = int('0b1110',2)
print('inteiro: ',x2)
# Out:
# binário:  0b1110
# inteiro:  14

# %%
1 ^0 # diferentes
# Out:
# 1

# %%
1 ^ 1  #iguais
# Out:
# 0

# %%
# NOT operation
bin(0b1010 ^ 0b1111)
# Out:
# '0b101'

# %%
# NOT operation
bin(0b0010 ^ 0b1111)
# Out:
# '0b1101'

# %%
# and operation
bin(0b0010 and 0b1111) # não deu certo com o and, tem que usar o &
# Out:
# '0b1111'

# %%
# and operation
bin(0b0010 & 0b1111)
# Out:
# '0b10'

# %%
# and operation
bin(0b0010 or 0b1111) # não deu certo com o or, tem que usar o |
# Out:
# '0b10'

# %%
# and operation
bin(0b0010 | 0b1111)
# Out:
# '0b1111'

# %% [markdown]
# usar => & |  ^

# %% [markdown]
# ### 3. Digital Circuits

# %% [markdown]
# ![image.png](attachment:dd21a300-4fd1-4e4a-829a-b8326a1fa8e5.png)

# %% [markdown]
# ![image.png](attachment:07db8452-9289-4f24-8947-03dd49182720.png)

# %% [markdown]
# ![image.png](attachment:883be470-1a3f-48ab-bcda-f1678c088cba.png)

# %% [markdown]
# ![image.png](attachment:dfedd0c6-1aae-4928-bf03-823d1bf12e17.png)

# %% [markdown]
# https://learnquantum.io/chapters/01_classical_computing/01_01_bits_and_circuits.html#digital-circuits
