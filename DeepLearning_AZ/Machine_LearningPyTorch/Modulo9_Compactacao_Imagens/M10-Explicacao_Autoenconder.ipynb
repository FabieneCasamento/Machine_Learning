# %%
# ambiente anaconda
import sys
print(sys.executable) # orange3 ou youtube
import sys
print(sys.version)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %% [markdown]
# ## 1) Autoencoders explicação base

# %% [markdown]
# ![image.png](attachment:f00a6e7f-2d53-4e3c-a163-7ac0280fdfb0.png)

# %% [markdown]
# ### Fazendo a codificação

# %% [markdown]
# ![image.png](attachment:270ac2ba-0573-416b-9de0-4104196651e6.png)

# %% [markdown]
# ### Agora faremos a decodificação
#
# multiplicar as linhas (pesos), pelos neurônios

# %% [markdown]
# ![image.png](attachment:94e9d759-1e0e-4652-9aa3-a0b05955280e.png)

# %% [markdown]
# Função de ativação, transforma os valores reais em 1 ou 0 apenas

# %% [markdown]
# ![image.png](attachment:87eb8818-b9ec-4444-a030-f76df9653b5a.png)

# %% [markdown]
# ## 2) Tipos de AutoEncoders

# %% [markdown]
# Tipos de autoencoders
#
#
# - redução da dimensionalidade
#
# autoencoders
#
# 50 neurônios entradas, para 5 neurônios de entradas
#
# - aumentar os neurônios na camada escondida.

# %% [markdown]
# 3 registros de entradas
# codificação
#
# 3 registros de saídas
# recodificação
#
# 5 neurônios da camada escondida, aumenta os dados
#
# autoencodres, para não repetir os dados

# %% [markdown]
# ![image.png](attachment:b48d245b-f67a-4153-9c72-000f4b62c0d3.png)

# %% [markdown]
# ## - sparse autoencoder
#
# Cada vez que executa ele desconsidera um neurônios específicos, evita o código a se adaptar aos dados.
#
# ![image.png](attachment:3ff44b01-aea9-40e8-ac0a-b62024261f8f.png)

# %% [markdown]
# ## * Denoising autoencoder
#
# - zera alguns neurônios de entrada, para evitar o overfitting
#
# - comparar os valores de saída com o de entradas
#
#
# ![image.png](attachment:9688b48c-8e0e-4549-a321-d265d4d80ff5.png)

# %% [markdown]
# ## *Contractive autoencoder
#
# Backingpropagation cálculo dos erros
#
# ![image.png](attachment:792f38a1-bdde-40a5-9f9e-26548466106d.png)

# %% [markdown]
# ## * deep autoencoder
#
# deep também chamado de stack, pilha
#
# empilhando os encoding e decoding

# %% [markdown]
# ![image.png](attachment:0888ffe5-3855-47a8-a62a-38b1a0100162.png)

# %% [markdown]
# ## * Convolutional autoencoder
#
# baseado em redes neurais convolucionais:
#
# camada de convolução reduzindo a dimensionalidade.
#
# Flatten vetor de características, com posições (números).
#
# FC, fluxo inverso.
#
#
# ![image.png](attachment:de29c6fd-fef7-4c6b-864c-194e5800ddda.png)
