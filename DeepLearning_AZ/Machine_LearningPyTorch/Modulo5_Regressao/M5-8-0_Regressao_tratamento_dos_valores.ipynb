# %% [markdown]
# Anaconda ambiente YouTube no linux

# %% [markdown]
# Na Classificação prevemos classes e na regressão prevemos números

# %% [markdown]
# # Projeto 8: Regressão carros usados
#
# ## Etapa 1: Importação das bibliotecas

# %%
import pandas as pd
import torch
import numpy as np
import seaborn as sns
from torch import nn, optim # otimizador
import torch.nn.functional as F # funcional
torch.__version__
# Out:
# '2.8.0+cu128'

# %% [markdown]
# ## Etapa 2: Base de dados

# %% [markdown]
# Codificação para a reprodutibilidade, para sempre termos os mesmos resultados.

# %%
np.random.seed(123)
torch.manual_seed(123)

# %%
base = pd.read_csv('autos.csv', encoding = 'ISO-8859-1')

# %%
base.tail()
# Out:
#                 dateCrawled                                          name  \
# 371523  2016-03-14 17:48:27                    Suche_t4___vito_ab_6_sitze
# 371524  2016-03-05 19:56:21         Smart_smart_leistungssteigerung_100ps
# 371525  2016-03-19 18:57:12            Volkswagen_Multivan_T4_TDI_7DC_UY2
# 371526  2016-03-20 19:41:08                        VW_Golf_Kombi_1_9l_TDI
# 371527  2016-03-07 19:39:19  BMW_M135i_vollausgestattet_NP_52.720____Euro
#
#         seller offerType  price   abtest vehicleType  yearOfRegistration  \
# 371523  privat   Angebot   2200     test         NaN                2005
# 371524  privat   Angebot   1199     test      cabrio                2000
# 371525  privat   Angebot   9200     test         bus                1996
# 371526  privat   Angebot   3400     test       kombi                2002
# 371527  privat   Angebot  28990  control   limousine                2013
#
#           gearbox  powerPS        model  kilometer  monthOfRegistration  \
# 371523        NaN        0          NaN      20000                    1
# 371524  automatik      101       fortwo     125000                    3
# 371525    manuell      102  transporter     150000                    3
# 371526    manuell      100         golf     150000                    6
# 371527    manuell      320      m_reihe      50000                    8
#
#        fuelType           brand notRepairedDamage          dateCreated  \
# 371523      NaN  sonstige_autos               NaN  2016-03-14 00:00:00
# 371524   benzin           smart              nein  2016-03-05 00:00:00
# 371525   diesel      volkswagen              nein  2016-03-19 00:00:00
# 371526   diesel      volkswagen               NaN  2016-03-20 00:00:00
# 371527   benzin             bmw              nein  2016-03-07 00:00:00
#
#         nrOfPictures  postalCode             lastSeen
# 371523             0       39576  2016-04-06 00:46:52
# 371524             0       26135  2016-03-11 18:17:12
# 371525             0       87439  2016-04-07 07:15:26
# 371526             0       40764  2016-03-24 12:45:21
# 371527             0       73326  2016-03-22 03:17:10

# %%
base.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %% [markdown]
# # utilizar algum desses atributos para fazer a previsão dos preços

# %%
base.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
# apagar alguns atributos que não são muito relevantes. 


# datas no momento não nos interessa
#'dateCrawled', 
#'dateCreated',
#'nrOfPictures', número de fotos não interfere
#'postalCode' no momento o cep não importa
#  'lastSeen' data da última visualização no site.

# %%
# faremos a limpeza dos dados, 
# manterá as colunas:

# 'name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType', 'yearOfRegistration'
# 'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 
#  'fuelType', 'brand',
#  'notRepairedDamage', 'dateCreated',

# %%
base.shape
# Out:
# (371528, 20)

# %%
print(f'Quantidades de registros na nossa base de dados auto.csv são de {base.shape[0]} e com {base.shape[1]} colunas ou atributos.')
# Out:
# Quantidades de registros na nossa base de dados auto.csv são de 371528 e com 20 colunas ou atributos.

# %%
# axis =1 apaga a coluna
# axis = 0 apaga a linha

# %% [markdown]
# ### Eliminar 5 colunas

# %%
base = base.drop('dateCrawled', axis = 1)
base = base.drop('dateCreated', axis = 1)
base = base.drop('nrOfPictures', axis = 1)
base = base.drop('postalCode', axis = 1)
base = base.drop('lastSeen', axis = 1)

# %%
base.shape
# Out:
# (371528, 15)

# %%
print(f'Quantidades de registros na nossa base de dados auto.csv são de {base.shape[0]} e com nova quantidade de colunas ou atributos:{base.shape[1]}.')
# Out:
# Quantidades de registros na nossa base de dados auto.csv são de 371528 e com nova quantidade de colunas ou atributos:15.

# %%
base.head()
# Out:
#                              name  seller offerType  price abtest vehicleType  \
# 0                      Golf_3_1.6  privat   Angebot    480   test         NaN
# 1            A5_Sportback_2.7_Tdi  privat   Angebot  18300   test       coupe
# 2  Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800   test         suv
# 3              GOLF_4_1_4__3TÜRER  privat   Angebot   1500   test  kleinwagen
# 4  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600   test  kleinwagen
#
#    yearOfRegistration    gearbox  powerPS  model  kilometer  \
# 0                1993    manuell        0   golf     150000
# 1                2011    manuell      190    NaN     125000
# 2                2004  automatik      163  grand     125000
# 3                2001    manuell       75   golf     150000
# 4                2008    manuell       69  fabia      90000
#
#    monthOfRegistration fuelType       brand notRepairedDamage
# 0                    0   benzin  volkswagen               NaN
# 1                    5   diesel        audi                ja
# 2                    8   diesel        jeep               NaN
# 3                    6   benzin  volkswagen              nein
# 4                    7   diesel       skoda              nein

# %%
# análise dos nomes dos carros
base['name'].value_counts()
# Out:
# name
# Ford_Fiesta                                              657
# BMW_318i                                                 627
# Opel_Corsa                                               622
# Volkswagen_Golf_1.4                                      603
# BMW_316i                                                 523
#                                                         ...
# Audi_A4_Avant_Klima_Gruene_Plakette_TÜV_&AU_NEU_XENON      1
# Renault_clio_in_gold_450VB_!!                              1
# Fiat_Doblo_1.6_Multijet                                    1
# Renault_Laguna_1                                           1
# BMW_M135i_vollausgestattet_NP_52.720____Euro               1
# Name: count, Length: 233531, dtype: int64

# %%
base['name'].unique()
# Out:
# array(['Golf_3_1.6', 'A5_Sportback_2.7_Tdi',
#        'Jeep_Grand_Cherokee_"Overland"', ...,
#        'Smart_smart_leistungssteigerung_100ps', 'VW_Golf_Kombi_1_9l_TDI',
#        'BMW_M135i_vollausgestattet_NP_52.720____Euro'], dtype=object)

# %%
len(base['name'].unique()) # quantidade de nomes dos carros.
# Out:
# 233531

# %%
# name será substituido por model:
base['model'].unique()
# Out:
# array(['golf', nan, 'grand', 'fabia', '3er', '2_reihe', 'andere', 'c_max',
#        '3_reihe', 'passat', 'navara', 'ka', 'polo', 'twingo', 'a_klasse',
#        'scirocco', '5er', 'meriva', 'arosa', 'c4', 'civic', 'transporter',
#        'punto', 'e_klasse', 'clio', 'kadett', 'kangoo', 'corsa', 'one',
#        'fortwo', '1er', 'b_klasse', 'signum', 'astra', 'a8', 'jetta',
#        'fiesta', 'c_klasse', 'micra', 'vito', 'sprinter', '156', 'escort',
#        'forester', 'xc_reihe', 'scenic', 'a4', 'a1', 'insignia', 'combo',
#        'focus', 'tt', 'a6', 'jazz', 'omega', 'slk', '7er', '80', '147',
#        'glk', '100', 'z_reihe', 'sportage', 'sorento', 'v40', 'ibiza',
#        'mustang', 'eos', 'touran', 'getz', 'a3', 'almera', 'megane',
#        'lupo', 'r19', 'zafira', 'caddy', 'mondeo', 'cordoba', 'colt',
#        'impreza', 'vectra', 'berlingo', 'm_klasse', 'tiguan', 'i_reihe',
#        'espace', 'sharan', '6_reihe', 'panda', 'up', 'seicento', 'ceed',
#        '5_reihe', 'yeti', 'octavia', 'mii', 'rx_reihe', '6er', 'modus',
#        'fox', 'matiz', 'beetle', 'c1', 'rio', 'touareg', 'logan',
#        'spider', 'cuore', 's_max', 'a2', 'x_reihe', 'a5', 'galaxy', 'c3',
#        'viano', 's_klasse', '1_reihe', 'avensis', 'sl', 'roomster', 'q5',
#        'kaefer', 'santa', 'cooper', 'leon', '4_reihe', '500', 'laguna',
#        'ptcruiser', 'clk', 'primera', 'exeo', '159', 'transit', 'juke',
#        'qashqai', 'carisma', 'accord', 'corolla', 'lanos', 'phaeton',
#        'boxster', 'verso', 'swift', 'rav', 'kuga', 'picanto', 'kalos',
#        'superb', 'stilo', 'alhambra', '911', 'mx_reihe', 'm_reihe',
#        'roadster', 'ypsilon', 'cayenne', 'galant', 'justy', '90',
#        'sirion', 'crossfire', 'agila', 'duster', 'cr_reihe', 'v50',
#        'discovery', 'c_reihe', 'v_klasse', 'yaris', 'c5', 'aygo', 'cc',
#        'carnival', 'fusion', 'bora', 'forfour', 'cl', 'tigra', '300c',
#        'q3', 'spark', 'v70', 'x_type', 'ducato', 's_type', 'x_trail',
#        'toledo', 'altea', 'voyager', 'calibra', 'bravo', 'range_rover',
#        'antara', 'tucson', 'q7', 'citigo', 'jimny', 'cx_reihe',
#        'wrangler', 'lybra', 'range_rover_sport', 'lancer', 'freelander',
#        'captiva', 'c2', 'range_rover_evoque', 'sandero', 'note', '900',
#        'defender', 'cherokee', 'clubman', 'samara', '601', 'legacy',
#        'pajero', 'auris', 'niva', 's60', 'nubira', 'vivaro', 'g_klasse',
#        'lodgy', '850', 'serie_2', 'charade', 'croma', 'outlander', 'gl',
#        'doblo', 'musa', 'amarok', 'move', '9000', 'v60', '145', 'aveo',
#        '200', 'b_max', 'delta', 'terios', 'rangerover', 'materia',
#        'kalina', 'elefantino', 'i3', 'kappa', 'serie_3', 'serie_1',
#        'discovery_sport'], dtype=object)

# %%
base['model'].value_counts()
# Out:
# model
# golf               30070
# andere             26400
# 3er                20567
# polo               13092
# corsa              12573
#                    ...
# serie_2                8
# rangerover             6
# serie_3                4
# serie_1                2
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %%
len(base['model'].unique()) # quantidade de modelos dos carros.
# Out:
# 252

# %%
# apagaremos a coluna name
base = base.drop('name', axis = 1)

# %%
# vendedor
base['seller'].value_counts()
# Out:
# seller
# privat        371525
# gewerblich         3
# Name: count, dtype: int64

# %% [markdown]
# privat - privado
#
# gewerblich  - acessível

# %%
# apagaremos a coluna seller, pois não faz diferença, a maioria é para o privado.
base = base.drop('seller', axis = 1)

# %%
base['offerType'].value_counts() # está bem desbalanceado, igual o seller, mais para um do que para outro
# Out:
# offerType
# Angebot    371516
# Gesuch         12
# Name: count, dtype: int64

# %%
base = base.drop('offerType', axis = 1)

# %%
base.head()
# Out:
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein

# %%
print(f'Quantidades de registros na nossa base de dados auto.csv são de {base.shape[0]} e com nova quantidade de colunas ou atributos:{base.shape[1]}.')
# Out:
# Quantidades de registros na nossa base de dados auto.csv são de 371528 e com nova quantidade de colunas ou atributos:12.

# %% [markdown]
# ## Verificar se tem um preço inconsistente

# %%
# ver se tem carros como preço abaixo ou igual aos 10 euros
i1 = base.loc[base.price <= 10]

# %%
i1.shape
# Out:
# (12118, 12)

# %%
base = base[base.price > 10]

# %%
base.shape
# Out:
# (359410, 12)

# %%
base.shape
# Out:
# (359410, 12)

# %%
import plotly.express as px
import plotly.graph_objects as go

#grafico = px.scatter(y = base['price'], title='<b>Amostra dos dados preços de carros.</b>')

#grafico.update_layout(
#    xaxis_title_text='X',
#    yaxis_title_text='Price',
    # padrão o título
#    title_font_size=20,  # Define o tamanho da fonte do título
#    title_font_family='Arial Black', # Uma fonte mais grossa
#    title_x=0.5 # Centraliza o título no gráfico
#)

#grafico.show()
#grafico.write_html("grafico1.html")

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = base.reset_index(drop=True)
# 2. Plotar o gráfico de linha
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.plot( df['price'], marker='o', linestyle='-', color='b')

# 3. Adicionar títulos e rótulos
plt.title('Variação do Preço ao Longo do Tempo', fontsize=16)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Preço ($ Euro)', fontsize=12)
plt.grid(True) # Adiciona uma grade para facilitar a leitura
plt.show()

# %%
# outlier

i2 = base.loc[base.price > 350000]
i2.shape
# Out:
# (115, 12)

# %%
# retirar os outliers
base = base.loc[base.price < 350000]

# %%
base.shape
# Out:
# (359291, 12)

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = base.reset_index(drop=True)
# 2. Plotar o gráfico de linha
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.plot( df['price'], marker='o', linestyle='-', color='b')

# 3. Adicionar títulos e rótulos
plt.title('Variação do Preço ao Longo do Tempo', fontsize=16)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Preço ($ Euro)', fontsize=12)
plt.grid(True) # Adiciona uma grade para facilitar a leitura
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Preparar os dados de exemplo
# Gerando 100 preços aleatórios para o exemplo
#prices = np.random.normal(loc=150, scale=20, size=500)

# 2. Plotar o histograma
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=20, color='skyblue', edgecolor='black')

# 3. Adicionar títulos e rótulos
plt.title('Distribuição de Preços', fontsize=16)
plt.xlabel('Intervalo de Preço', fontsize=12)
plt.ylabel('Frequência (Contagem)', fontsize=12)
plt.grid(axis='y', alpha=0.75) # Adiciona uma grade no eixo Y
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Preparar os dados de exemplo
# Gerando 100 preços aleatórios para o exemplo
#prices = np.random.normal(loc=150, scale=20, size=500)

# 2. Plotar o histograma
plt.figure(figsize=(10, 6))
plt.hist(df['price'], bins=100, color='skyblue', edgecolor='black')

# 3. Adicionar títulos e rótulos
plt.title('Distribuição de Preços', fontsize=16)
plt.xlabel('Intervalo de Preço', fontsize=12)
plt.ylabel('Frequência (Contagem)', fontsize=12)
plt.grid(axis='y', alpha=0.75) # Adiciona uma grade no eixo Y
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


df = base.reset_index(drop=True)

# 2. Plotar o gráfico de linha
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.plot(df['price'], marker='o', linestyle='-', color='b')

# --- Adicionar esta linha para definir os limites do eixo Y ---
plt.ylim(10, 20)

# 3. Adicionar títulos e rótulos
plt.title('Variação do Preço ao Longo do Tempo', fontsize=16)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Preço ($ Euro)', fontsize=12)
plt.grid(True) # Adiciona uma grade para facilitar a leitura
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np


# 2. Plotar o gráfico de linha
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
plt.plot(df['price'], marker='o', linestyle='-', color='b')

# --- Adicionar esta linha para definir os limites do eixo Y ---
plt.ylim(10, 350000)

# 3. Adicionar títulos e rótulos
plt.title('Variação do Preço ao Longo do Tempo', fontsize=16)
plt.xlabel('Data', fontsize=12)
plt.ylabel('Preço ($ Euro)', fontsize=12)
plt.grid(True) # Adiciona uma grade para facilitar a leitura
plt.show()

# %% [markdown]
# ## tratamentos dos valores nulos

# %%
# verificar com o mapa de calores os dados nulos
sns.heatmap(base.isnull())
# Out:
# <Axes: >

# %%
base.isnull().sum()
# Out:
# price                      0
# abtest                     0
# vehicleType            33546
# yearOfRegistration         0
# gearbox                17236
# powerPS                    0
# model                  17967
# kilometer                  0
# monthOfRegistration        0
# fuelType               29391
# brand                      0
# notRepairedDamage      65986
# dtype: int64

# %% [markdown]
# X atributos
#
# y - valores dos registros

# %%
# valores nulos nas figuras estão em branco. Branco nulos nas posições.

# %% [markdown]
# ### O que tem mais valores nulos é a coluna 'notRepairedDamage'.

# %% [markdown]
# ## Analisar o tipo do veículo

# %% [markdown]
# ##  vehicleType

# %%
base.loc[pd.isnull(base['vehicleType'])].tail(20) # verificar os valores nulos
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371258   3600     test         NaN                2017    manuell       86
# 371261    299     test         NaN                2016    manuell       60
# 371274    400     test         NaN                2000        NaN        0
# 371286   1000  control         NaN                2017    manuell      101
# 371309   1500  control         NaN                1995        NaN        0
# 371316   3000  control         NaN                2016    manuell        0
# 371349   1350     test         NaN                2016    manuell        0
# 371354   2140     test         NaN                2018    manuell       80
# 371359   8700     test         NaN                2009        NaN        0
# 371370    790     test         NaN                1990    manuell        0
# 371380   9000     test         NaN                2008        NaN        0
# 371407   1250     test         NaN                2018        NaN        0
# 371444   5000  control         NaN                2017    manuell      120
# 371460   3500  control         NaN                1995        NaN        0
# 371493   3299     test         NaN                2005  automatik        0
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#             model  kilometer  monthOfRegistration fuelType           brand  \
# 371258    transit     150000                    5   diesel            ford
# 371261      astra     150000                    4   benzin            opel
# 371274     twingo     150000                    0      NaN         renault
# 371286         a4     150000                    9      NaN            audi
# 371309        NaN     150000                    0      NaN      volkswagen
# 371316       colt     150000                    8   diesel      mitsubishi
# 371349        clk     150000                    8      NaN   mercedes_benz
# 371354     fiesta     150000                    6      NaN            ford
# 371359    2_reihe      90000                    8   benzin         peugeot
# 371370     andere     150000                    1   benzin         renault
# 371380        1er     125000                    0      NaN             bmw
# 371407      corsa     150000                    0   benzin            opel
# 371444     andere     150000                    7      NaN         citroen
# 371460       polo     150000                    0      NaN      volkswagen
# 371493  outlander     150000                    4   benzin      mitsubishi
# 371495        NaN     125000                    3   benzin            opel
# 371504   c_klasse     150000                    9      NaN   mercedes_benz
# 371509        NaN     150000                    7      NaN      volkswagen
# 371519        159     150000                   12      NaN      alfa_romeo
# 371523        NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 371258               NaN
# 371261                ja
# 371274               NaN
# 371286               NaN
# 371309               NaN
# 371316              nein
# 371349                ja
# 371354              nein
# 371359               NaN
# 371370               NaN
# 371380               NaN
# 371407               NaN
# 371444                ja
# 371460               NaN
# 371493               NaN
# 371495               NaN
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN

# %%
len(base.loc[pd.isnull(base['vehicleType'])])
# Out:
# 33546

# %%
base['vehicleType'].value_counts() # limousine é o veículo que mais aparece
# Out:
# vehicleType
# limousine     93614
# kleinwagen    78014
# kombi         65921
# bus           29699
# cabrio        22509
# coupe         18386
# suv           14477
# andere         3125
# Name: count, dtype: int64

# %%
base['vehicleType'].unique()
# Out:
# array([nan, 'coupe', 'suv', 'kleinwagen', 'limousine', 'cabrio', 'bus',
#        'kombi', 'andere'], dtype=object)

# %% [markdown]
# apagar o NaN ou substituir os valores da coluna vehicleType

# %% [markdown]
# ## gearbox

# %%
len(base.loc[pd.isnull(base['gearbox'])])
# Out:
# 17236

# %%
base.loc[pd.isnull(base['gearbox'])].tail()
# Out:
#         price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 371443   3300  control       kombi                2006     NaN        0
# 371460   3500  control         NaN                1995     NaN        0
# 371486    350  control  kleinwagen                1996     NaN       65
# 371495    180  control         NaN                1995     NaN        0
# 371523   2200     test         NaN                2005     NaN        0
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 371443  touran     150000                    7   diesel      volkswagen
# 371460    polo     150000                    0      NaN      volkswagen
# 371486   punto     150000                    0      NaN            fiat
# 371495     NaN     125000                    3   benzin            opel
# 371523     NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 371443               NaN
# 371460               NaN
# 371486               NaN
# 371495               NaN
# 371523               NaN

# %%
base['gearbox'].unique()
# Out:
# array(['manuell', 'automatik', nan], dtype=object)

# %%
base['gearbox'].value_counts() # manuell
# Out:
# gearbox
# manuell      266547
# automatik     75508
# Name: count, dtype: int64

# %% [markdown]
# ## model

# %%
len(base.loc[pd.isnull(base['model'])])
# Out:
# 17967

# %%
base.loc[pd.isnull(base['model'])].tail(20)
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371065  18500     test   limousine                2009  automatik      190
# 371099    200  control         NaN                1910        NaN        0
# 371102   1599     test  kleinwagen                2002    manuell       75
# 371110   1670  control         NaN                2018    manuell        0
# 371121   1500  control         bus                1984    manuell        0
# 371146  10980     test         NaN                2018    manuell       75
# 371150   1000  control         NaN                2017    manuell       54
# 371196  42000  control   limousine                2012  automatik      564
# 371203   6000     test  kleinwagen                2008    manuell      155
# 371214  30900  control      cabrio                1960  automatik      250
# 371216   1750     test         NaN                1995        NaN        0
# 371220    200  control  kleinwagen                1998    manuell       37
# 371223   4300     test  kleinwagen                2008  automatik        0
# 371309   1500  control         NaN                1995        NaN        0
# 371388   5000  control   limousine                2002  automatik      170
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
#        model  kilometer  monthOfRegistration fuelType           brand  \
# 371065   NaN     150000                   10   diesel            audi
# 371099   NaN       5000                    0   benzin  sonstige_autos
# 371102   NaN     150000                    0   benzin            ford
# 371110   NaN      90000                    0   benzin         renault
# 371121   NaN     150000                    5   diesel   mercedes_benz
# 371146   NaN      20000                    1      NaN      volkswagen
# 371150   NaN     125000                    2      NaN         hyundai
# 371196   NaN      50000                    3   benzin  sonstige_autos
# 371203   NaN     150000                    5   benzin  sonstige_autos
# 371214   NaN     100000                    7   benzin  sonstige_autos
# 371216   NaN     100000                   12      NaN  sonstige_autos
# 371220   NaN     150000                    4   benzin      volkswagen
# 371223   NaN     150000                    3      NaN           honda
# 371309   NaN     150000                    0      NaN      volkswagen
# 371388   NaN     150000                    0   benzin            audi
# 371399   NaN      90000                    0   benzin            fiat
# 371476   NaN     150000                    4   diesel  sonstige_autos
# 371495   NaN     125000                    3   benzin            opel
# 371509   NaN     150000                    7      NaN      volkswagen
# 371523   NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 371065              nein
# 371099               NaN
# 371102               NaN
# 371110              nein
# 371121               NaN
# 371146              nein
# 371150              nein
# 371196              nein
# 371203              nein
# 371214              nein
# 371216               NaN
# 371220                ja
# 371223               NaN
# 371309               NaN
# 371388              nein
# 371399                ja
# 371476                ja
# 371495               NaN
# 371509              nein
# 371523               NaN

# %%
base['model'].unique()
# Out:
# array(['golf', nan, 'grand', 'fabia', '3er', '2_reihe', 'c_max',
#        '3_reihe', 'passat', 'navara', 'ka', 'polo', 'twingo', 'a_klasse',
#        'scirocco', '5er', 'meriva', 'arosa', 'andere', 'c4', 'civic',
#        'transporter', 'punto', 'e_klasse', 'clio', 'kadett', 'kangoo',
#        'one', 'fortwo', '1er', 'b_klasse', 'signum', 'astra', 'a8',
#        'jetta', 'fiesta', 'c_klasse', 'micra', 'vito', 'sprinter', '156',
#        'escort', 'forester', 'xc_reihe', 'scenic', 'a4', 'a1', 'insignia',
#        'combo', 'focus', 'tt', 'corsa', 'a6', 'jazz', 'omega', 'slk',
#        '7er', '80', '147', 'glk', '100', 'z_reihe', 'sportage', 'sorento',
#        'v40', 'ibiza', 'mustang', 'eos', 'touran', 'getz', 'a3', 'almera',
#        'megane', 'lupo', 'r19', 'zafira', 'caddy', 'mondeo', 'cordoba',
#        'colt', 'impreza', 'vectra', 'berlingo', 'm_klasse', 'tiguan',
#        'i_reihe', 'espace', 'sharan', '6_reihe', 'panda', 'up',
#        'seicento', 'ceed', '5_reihe', 'yeti', 'octavia', 'mii',
#        'rx_reihe', '6er', 'modus', 'fox', 'matiz', 'beetle', 'c1', 'rio',
#        'touareg', 'logan', 'spider', 'cuore', 's_max', 'a2', 'x_reihe',
#        'a5', 'galaxy', 'c3', 'viano', 's_klasse', '1_reihe', 'avensis',
#        'sl', 'roomster', 'q5', 'kaefer', 'santa', 'cooper', 'leon',
#        '4_reihe', '500', 'laguna', 'ptcruiser', 'clk', 'primera', 'exeo',
#        '159', 'transit', 'juke', 'qashqai', 'carisma', 'accord',
#        'corolla', 'lanos', 'phaeton', 'boxster', 'verso', 'swift', 'rav',
#        'kuga', 'picanto', 'kalos', 'superb', 'stilo', 'alhambra', '911',
#        'm_reihe', 'roadster', 'ypsilon', 'cayenne', 'galant', 'justy',
#        '90', 'sirion', 'crossfire', 'agila', 'duster', 'cr_reihe', 'v50',
#        'mx_reihe', 'discovery', 'c_reihe', 'v_klasse', 'yaris', 'c5',
#        'aygo', 'cc', 'carnival', 'fusion', 'bora', 'forfour', 'cl',
#        'tigra', '300c', 'q3', 'spark', 'v70', 'x_type', 'ducato',
#        's_type', 'x_trail', 'toledo', 'altea', 'voyager', 'calibra',
#        'bravo', 'range_rover', 'antara', 'tucson', 'q7', 'citigo',
#        'jimny', 'cx_reihe', 'wrangler', 'lybra', 'range_rover_sport',
#        'lancer', 'freelander', 'captiva', 'c2', 'range_rover_evoque',
#        'sandero', 'note', '900', 'defender', 'cherokee', 'clubman',
#        'samara', '601', 'legacy', 'pajero', 'auris', 'niva', 's60',
#        'nubira', 'vivaro', 'g_klasse', 'lodgy', '850', 'serie_2',
#        'charade', 'croma', 'outlander', 'gl', 'doblo', 'musa', 'amarok',
#        'move', '9000', 'v60', '145', 'aveo', '200', 'b_max', 'delta',
#        'terios', 'rangerover', 'materia', 'kalina', 'elefantino', 'i3',
#        'kappa', 'serie_3', 'serie_1', 'discovery_sport'], dtype=object)

# %%
base['model'].value_counts() # golf
# Out:
# model
# golf               28989
# andere             25560
# 3er                19905
# polo               12604
# corsa              12149
#                    ...
# serie_2                8
# rangerover             6
# serie_3                3
# serie_1                1
# discovery_sport        1
# Name: count, Length: 251, dtype: int64

# %% [markdown]
# ## fuelType

# %%
len(base.loc[pd.isnull(base['fuelType'])])
# Out:
# 29391

# %%
base.loc[pd.isnull(base['fuelType'])].tail()
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371496   3850     test      cabrio                2006    manuell      108
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 371496   2_reihe     125000                    2      NaN         peugeot
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 371496              nein
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN

# %%
base['fuelType'].value_counts() # benzin
# Out:
# fuelType
# benzin     217582
# diesel     106002
# lpg          5222
# cng           557
# hybrid        271
# andere        165
# elektro       101
# Name: count, dtype: int64

# %%
base['fuelType'].unique()
# Out:
# array(['benzin', 'diesel', nan, 'lpg', 'andere', 'hybrid', 'cng',
#        'elektro'], dtype=object)

# %% [markdown]
# # último atributo  notRepairedDamage

# %%
base.loc[pd.isnull(base['notRepairedDamage'])].tail()
# Out:
#         price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 371507   5999     test       kombi                2005  manuell      140
# 371514    999  control      cabrio                2000  manuell       95
# 371515   1690     test       kombi                2004  manuell       55
# 371523   2200     test         NaN                2005      NaN        0
# 371526   3400     test       kombi                2002  manuell      100
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 371507      a4     150000                    4   diesel            audi
# 371514  megane     150000                    4   benzin         renault
# 371515   fabia     150000                    4   benzin           skoda
# 371523     NaN      20000                    1      NaN  sonstige_autos
# 371526    golf     150000                    6   diesel      volkswagen
#
#        notRepairedDamage
# 371507               NaN
# 371514               NaN
# 371515               NaN
# 371523               NaN
# 371526               NaN

# %%
len(base.loc[pd.isnull(base['notRepairedDamage'])])
# Out:
# 65986

# %%
base['notRepairedDamage'].value_counts() # nein
# Out:
# notRepairedDamage
# nein    259301
# ja       34004
# Name: count, dtype: int64

# %% [markdown]
# nein => não
#
# ja  => sim

# %%
base['notRepairedDamage'].unique()
# Out:
# array([nan, 'ja', 'nein'], dtype=object)

# %%
base.loc[pd.isnull(base['price'])]
# Out:
# Empty DataFrame
# Columns: [price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage]
# Index: []

# %% [markdown]
# ## Valores no formato do dicionário para preencher os dados nulos

# %%
valores = {'vehicleType': 'limousine', 'gearbox': 'manuell',
           'model': 'golf', 'fuelType': 'benzin',
           'notRepairedDamage': 'nein'}
# colunas: valores que mais aparecem

# %%
base = base.fillna(value = valores)

# %%
base.tail()
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 371523   2200     test   limousine                2005    manuell        0
# 371524   1199     test      cabrio                2000  automatik      101
# 371525   9200     test         bus                1996    manuell      102
# 371526   3400     test       kombi                2002    manuell      100
# 371527  28990  control   limousine                2013    manuell      320
#
#               model  kilometer  monthOfRegistration fuelType           brand  \
# 371523         golf      20000                    1   benzin  sonstige_autos
# 371524       fortwo     125000                    3   benzin           smart
# 371525  transporter     150000                    3   diesel      volkswagen
# 371526         golf     150000                    6   diesel      volkswagen
# 371527      m_reihe      50000                    8   benzin             bmw
#
#        notRepairedDamage
# 371523              nein
# 371524              nein
# 371525              nein
# 371526              nein
# 371527              nein

# %%
base.isnull().sum()
# Out:
# price                  0
# abtest                 0
# vehicleType            0
# yearOfRegistration     0
# gearbox                0
# powerPS                0
# model                  0
# kilometer              0
# monthOfRegistration    0
# fuelType               0
# brand                  0
# notRepairedDamage      0
# dtype: int64

# %%
# fazer testes
base.loc[pd.isnull(base['notRepairedDamage'])]
# Out:
# Empty DataFrame
# Columns: [price, abtest, vehicleType, yearOfRegistration, gearbox, powerPS, model, kilometer, monthOfRegistration, fuelType, brand, notRepairedDamage]
# Index: []

# %% [markdown]
# ## Terceiro tratamento dos dados

# %% [markdown]
# # Pré processamento adicionais

# %%
# 0 é o nosso objetivo preço

# %%
base.columns[1:13]
# Out:
# Index(['abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS',
#        'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage'],
#       dtype='object')

# %%
 base.columns[0]
# Out:
# 'price'

# %%
base.shape
# Out:
# (359291, 12)

# %%
previsores = base.iloc[:, 1:13].values
preco_real = base.iloc[:, 0].values

# %%
previsores.shape
# Out:
# (359291, 11)

# %%
preco_real.shape
# Out:
# (359291,)

# %% [markdown]
# # Transformar os atributos categoricos em númericos

# %% [markdown]
# ## ideia para usar o OneHotEncoder

# %%
# temos que ter cuidado para o tipo

# fazer a representação única
# gol  1 0 0
# pali 0 1 0
# uno  0 0 1

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# 0 0 0
# 0 1 0
# 0 0 1

# %%
atributos = base.iloc[:, 1:13].tail(2).reset_index(drop=True)
atributos
# Out:
#     abtest vehicleType  yearOfRegistration  gearbox  powerPS    model  \
# 0     test       kombi                2002  manuell      100     golf
# 1  control   limousine                2013  manuell      320  m_reihe
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage
# 0     150000                    6   diesel  volkswagen              nein
# 1      50000                    8   benzin         bmw              nein

# %%
len(list(atributos.columns))
# Out:
# 11

# %%
print(list(atributos.columns))
# Out:
# ['abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage']

# %%
# Encontra a posição (índice) da coluna 'price'

for col in list(atributos.columns):

   posicao_col = df.columns.get_loc(f'{col}')
    
   print(f"O índice da coluna {col} é: {posicao_col-1}")
# Out:
# O índice da coluna abtest é: 0
# O índice da coluna vehicleType é: 1
# O índice da coluna yearOfRegistration é: 2
# O índice da coluna gearbox é: 3
# O índice da coluna powerPS é: 4
# O índice da coluna model é: 5
# O índice da coluna kilometer é: 6
# O índice da coluna monthOfRegistration é: 7
# O índice da coluna fuelType é: 8
# O índice da coluna brand é: 9
# O índice da coluna notRepairedDamage é: 10

# %%
# transformer em forma de lista

onehotencoder = ColumnTransformer(transformers = [("OneHot", OneHotEncoder(), # encoder para fazer as transformações
                                                   [0,1,3,5,8,9,10])], # índices dos atributos que queremos transformar. Número das colunas
                                  remainder = 'passthrough') 
 # remainder = 'passthrough' =>passar pelas colunas restantes, e vai 
#se não tiver o padrão é drop e as colunas  [0,1,3,5,8,9,10] serão apagadas

# %%
# para colocar no formato encoder único e no formato array
previsores = onehotencoder.fit_transform(previsores).toarray()

# %%
previsores
# Out:
# array([[0.00e+00, 1.00e+00, 0.00e+00, ..., 0.00e+00, 1.50e+05, 0.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.90e+02, 1.25e+05, 5.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.63e+02, 1.25e+05, 8.00e+00],
#        ...,
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.02e+02, 1.50e+05, 3.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, ..., 1.00e+02, 1.50e+05, 6.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, ..., 3.20e+02, 5.00e+04, 8.00e+00]])

# %%
previsores.shape
# Out:
# (359291, 316)

# %%
# se tivermos 100 tipos de carros será criado no onehotencoder mais 100 novas colunas.

# %%
previsores[0] #posicionamentos do primeiro registro
# Out:
# array([0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#        0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00,
#        1.993e+03, 0.000e+00, 1.500e+05, 0.000e+00])

# %%
type(previsores)
# Out:
# numpy.ndarray

# %%
previsores = torch.tensor(previsores, dtype = torch.float)
preco_real = torch.tensor(preco_real, dtype = torch.float).view(-1, 1) # como um reshape para definir a posição

# %%
type(previsores)
# Out:
# torch.Tensor

# %%
preco_real.shape # formato de matriz
# Out:
# torch.Size([359291, 1])
