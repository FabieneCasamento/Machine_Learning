# %%
# ambiente anaconda
import sys
print(sys.executable) # orange3 ou youtube
import sys
print(sys.version)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %% [markdown]
# Detecção do objeto personalizado transfer learning no pytorch
#
# Treinar a rede exaustivamente
#
# ![image.png](attachment:1c03fe18-841e-4278-aca5-42be844b9c3b.png)

# %% [markdown]
# Processo roda uma única vez.
#
# Vgg16 para imagens, prever ou classificação.
#
# No total são um milhão de imagens.
#
# Rede do transfer, já disponível e treinados

# %% [markdown]
# ![image.png](attachment:0c8768c7-22c2-4301-8b7b-d397e10dc84a.png)

# %% [markdown]
# Pesos ajustados, para a tarefa da classificação
#
# vgg16 pois tem 16 camadas

# %% [markdown]
# 13 convolution + ReLU → camada densa e também no início de cada step
#
# cada step começa com mo max pooling, que resumi o processo.
#
# e + 3 fully nected +ReLU
#
# vetor com 1000 posições
# softmax
#
# 1x1000
#
# qual a probabilidade da imagem pertencer a cada uma das mil categorias originais
#
# última última cada do softmax

# %% [markdown]
# (((())))

# %% [markdown]
# primeiro input
#
# steps conjunto dos processos
#
#
# processos de convoluções conv
#
# #### primeiro modulo features, convoluções => extrair os features das imagens
#
# #### Segundo módulo, denso classificação

# %% [markdown]
# ![image.png](attachment:e3a60a7a-7acc-4887-9b79-a2032ecc4559.png)

# %% [markdown]
# Vgg16 para a tarefa específica
#
# fine-tuning ajustamento fino

# %% [markdown]
# Transfer learning, tem que adequar antes, fine-tuning
#
# as vezes tem qe alterar o final a parte densa
#
# geralmente tratando problemas mais restritos
#
# se treinamos o processo inteiro ou a parte, um pedaço
#
# isso pelo fine-tuning
#
# se vamos treinar a parte do parâmetro features ou treinar os parâmetros de classificação, processo ou decisão empírica.
#
# Ver qual a decisão tem o desempenho melhor.
#
# A pesquisa ou conhecimento empírico baseia-se na experiência prática, observação direta e coleta de dados na vida real, em contrapartida à teoria pura.
#
# Problemas da convoluções de vários parâmetros, o ideal é usar o fine tuning, para o processo final, de classificação.
