# %%
# ambiente anaconda
import sys
print(sys.executable) # orange3 ou youtube
import sys
print(sys.version)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %% [markdown]
# ## LSTM (Long-Short term memory)
#
# LSTM
# rede neural complementar a palavra.

# %% [markdown]
# ![image.png](attachment:9733333d-6f39-49ac-b653-bbc966818b31.png)

# %% [markdown]
# primeira parte simples:
#
# aplicação da função de ativação => tanh default tangente hiperbólica
#
#
# segunda parte => LSTM
#
#
# xt, entrada
#
# ht output
#
# além da parte da função da ativação, multiplacação do somatório do neurônio. Aplica a função de ativação, não passa direto, neste caso, faz vários tratamentos. Tendo o sigmoide ( σ( x ) = 1 / (1 + e − x ) )

# %% [markdown]
# forget fate -> x -> liberar da memória.
#
# Input gate -> + => adicionar na memória
#
# Output gate -> ir para o ht ou para o último A => ler da memória
#
# ![image.png](attachment:6cd4f8bb-0a34-49a5-add3-e3867e5d6dff.png)

# %% [markdown]
# ht-1 -> saída do tempo anterior
#
# xt -> valor atual
#
# entrada na função sigmoide, sair valores entre 0 e 1;
#
# função sigmoide para ver se a informação é importante ou não;
#
#
# ![image.png](attachment:b0241b83-669e-453d-96dd-c150c8d596cf.png)
#
#
# forget hate -> x -> liberar ou tirar da memória.

# %% [markdown]
# ------------------------
#
# ht-1 -> saída do tempo anterior
#
# xt -> valor atual
#
# entrada na função sigmoide, sair valores entre 0 e 1;
#
# valores alterados e usa a tangente hiperbólica que retorna valores entre -1 e 1.
#
#
# ![image.png](attachment:bb50e179-8545-4b3f-a3fb-2e6484791b52.png)

# %% [markdown]
# ----------------------------------------------
#
# x forget gate, passa na tangente, adicionar a nova informação no (+) e passar a informação para o Ct
#
# ![image.png](attachment:7c597f4b-feaa-4e69-ae7d-f4004d4a0304.png)

# %% [markdown]
# ------------
#
#
# Ot output gate
#
# sigmoide
# tangente hiperbólica, para retornar as partes necessárias (de -1 e 1) e passar para o ht
#
#
# célula de memória para o Ct
#
# ht tratando finalmente a saída.
#
#
# ![image.png](attachment:7f919330-471c-4283-82eb-3c8d5550d0de.png)

# %% [markdown]
# https://colah.github.io/posts/2015-08-Understanding-LSTMs/
