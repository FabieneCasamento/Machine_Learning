# %%
# ambiente anaconda
import sys
print(sys.executable) # orange3 ou youtube
import sys
print(sys.version)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %% [markdown]
# ## Teoria sobre redes neurais Recorrentes

# %% [markdown]
# prever o que a pessoa irá falar depois, e a que horas fará tal processo.
#
# tipo de cozinhar, qual tempero irá colocar.
#
# ![image.png](attachment:1c8e4016-602a-4daa-85b4-da91173cd32e.png)

# %% [markdown]
# Decrição de imagens
# convolutional neural network CNN
#
# Aplicando o Long Short Memory

# %% [markdown]
# ![image.png](attachment:25a91e17-fe3c-43a5-aa8c-fe7f9a154489.png)

# %% [markdown]
# Rede neural recorrente consegue fazer esse processo.
#
#
#
# Previsões independentes também , além da sequência

# %% [markdown]
# neurônios
#
# rede neral densa, chega a camada oculta e faz o cálculo da função de ativação, passando o valor para a segunda camada escondida, e passa o valor da ativação para a frente;
# Não armazena as informações,
#
# diferença básica da rede neural recorrente, que tem loops que as permintem que as informações persistam ao decorrer do temo;
#
# camadas escondidas Têm loops, além de passar a informação para a frente, armazena a informação na camada escondida, ao longo do tempo.
#
#
# A, neurônio
# passanda informação para ele mesmo.
#
#
#
# neurônios, que terá limite, que definimos um xt.
# h0 com tempop ht t= tempo.

# %% [markdown]
# ![image.png](attachment:5da1b8d4-c45a-4e87-8c26-5e1cdd706262.png)
#
# rede neural mais lenta, consequentemente.
