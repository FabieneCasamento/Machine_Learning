# %%
# ambiente anaconda
import sys
print(sys.executable) # orange3 ou youtube
import sys
print(sys.version)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %% [markdown]
# Redes neurais recorrentes, nas camadas ocultas tem ligação para fazer a forma recorrente.
#
# Parte replicada várias vezes.
#
# #### Unit ht número de células para o loop
#
# exemplo da rede neural densa, fazemos um achatamento dos neurônios da camada oculta
#
#
# _ não salva ou armazenar os valores ou os dados muito longe do tempo_

# %% [markdown]
# ![image.png](attachment:e88a5187-6db9-49a7-b114-5fdf6220ce1d.png)

# %% [markdown]
# #### O gradiente, quando o erro for alto, é ruim, a ideia é chegar no mínimo global, o cavado mais baixo.
#
# Descida do gradiente, neurônios, bolas
#
# Atualização dos pesos,backpropagation, muitas camadas, diminuindo o tempo dos valores da atualização dos pesos
# learning rate.
#
# ![image.png](attachment:270ccbc2-bf63-414b-b24d-062745dfc815.png)

# %% [markdown]
# Mudança dos pesos
#
# vanish gradient problema, do gradiente desaparecer. O gradiente fica com um valor muito pequeno.
#
#
# ![image.png](attachment:20ddf88f-3f85-4755-a9d8-a9f8a91521ce.png)

# %% [markdown]
# Inicialização dos pesos, xavier
#
# glorot normal => inicialização dos pesos
#
#
# ![image.png](attachment:3d4fef4a-b4e8-4678-a773-d824c121c50a.png)

# %% [markdown]
# GlorotNormal class
#
# https://keras.io/api/layers/initializers/

# %%
#eras.initializers.GlorotNormal(seed=None)
#The Glorot normal initializer, also called Xavier normal initializer.

#Draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / (fan_in + fan_out)) where fan_in is the number of input units in the weight tensor and fan_out is the number of output units in the weight tensor.

#Examples
#>>> # Standalone usage:
#>>> initializer = GlorotNormal()
#>>> values = initializer(shape=(2, 2))

#>>> # Usage in a Keras layer:
#>>> initializer = GlorotNormal()
#>>> layer = Dense(3, kernel_initializer=initializer)
#Arguments

#seed: A Python integer or instance of keras.backend.SeedGenerator.
#Used to make the behavior of the initializer deterministic. Note that an initializer seeded with an integer or None (unseeded) will produce the same random values across multiple calls. To get different random values across multiple calls, use as seed an instance of keras.backend.SeedGenerator.

# %% [markdown]
# ![image.png](attachment:39548ace-7434-4640-a89c-36979cb728e2.png)

# %% [markdown]
# Exploding não consegue chegar no mínimo global

# %% [markdown]
# ![image.png](attachment:c03008a8-b4ed-48ea-ad26-83d79d525206.png)

# %% [markdown]
# Não visitar as camadas ocultas pode solucionar, mas não é recomendado, não aprende;

# %% [markdown]
# RMSProd, recomendável para as redes neurais recorrentes para atualização dos pesos.
#
# Grampo barra a subida do gradiente, como 0,5

# %% [markdown]
# ![image.png](attachment:da60e5db-d3d1-4e70-afae-368853eb4ce5.png)
