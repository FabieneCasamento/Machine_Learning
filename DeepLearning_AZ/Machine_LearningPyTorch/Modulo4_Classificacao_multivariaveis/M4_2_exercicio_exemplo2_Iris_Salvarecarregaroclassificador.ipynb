# %% [markdown]
# # Tarefa: Iris - Salvar e carregar o classificador

# %% [markdown]
# Após executarmos o processo de tuning da rede neural e coletarmos quais são os melhores parâmetros, é hora de gerar o classificador final para que possamos usar em ambientes comerciais:
#
# - Treinar a rede neural utilizando a base de dados completa utilizando os melhores parâmetros que foram obtidos pelo tuning
#
# - Salvar a estrutura da rede neural
#
# - Carregar a rede neural salva no tópico anterior
#
# - Criar um novo registro (pode ser com dados aleatórios) no mesmo formato dos atributos previsores
#
# - Classificar o novo registro, indicando a que classe ele pertence

# %% [markdown]
# ## Etapa 1: Importação das bibliotecas

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import torch
from torch import nn, optim
from torch.nn import functional as F
torch.__version__
# Out:
# '2.8.0+cu128'

# %% [markdown]
# ## Etapa 2: Base de dados

# %%
torch.manual_seed(123)

# %%
base = pd.read_csv('iris.csv')
previsores = base.iloc[:, 0:4].values
classe = base.iloc[:, 4].values

# %%
encoder = LabelEncoder()
classe = encoder.fit_transform(classe)

# %%
previsores = torch.tensor(previsores, dtype = torch.float)
classe = torch.tensor(classe, dtype = torch.long)

# %%
dataset = torch.utils.data.TensorDataset(previsores, classe)
train_loader = torch.utils.data.DataLoader(dataset, batch_size = 10, shuffle = True)

# %% [markdown]
# ## Etapa 3: Construção do modelo

# %%
amostra_do_melhor_parametro = {'batch_size': 10,
 'max_epochs': 200,
 'module__activation': '<function torch.nn.functional.relu(input: torch.Tensor, inplace: bool = False) -> torch.Tensor>',
 'module__dropout': 0.2,
 'module__initializer': '<function torch.nn.init.uniform_(tensor: torch.Tensor, a: float = 0.0, b: float = 1.0, generator: Optional[torch._C.Generator] = None) -> torch.Tensor>',
 'module__neurons': 16,
 'optimizer': 'torch.optim.adam.Adam'}

# %%
classificador = nn.Sequential(
                nn.Linear(4, 16),
                nn.ReLU(),
                nn.Dropout(0.2),
                nn.Linear(16, 16),
                nn.ReLU(),
                nn.Dropout(0.2),
                nn.Linear(16, 3),
                )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(classificador.parameters(), lr = 0.001, weight_decay = 0.0001)

# %% [markdown]
# ## Etapa 4: Treinamento do modelo

# %% [markdown]
# **ciclo de treinamento de uma rede neural**.
#
# Ele executa o processo de aprendizado passo a passo, ajustando os pesos do modelo para que ele melhore na tarefa de fazer previsões.
#
# O processo pode ser resumido em dois grandes loops:
#
# **O Ciclo da Época**
# A primeira linha, *for epoch in range(2000):*, inicia o ciclo da época. Uma época é uma passagem completa por todo o conjunto de dados de treinamento. Repetir isso 2000 vezes permite que o modelo refine seus pesos continuamente. A cada nova época, as variáveis running_loss e running_accuracy são zeradas para registrar o desempenho daquela rodada.
#
#
# **O Ciclo do Mini-Lote**
# O loop interno, for data in *train_loader:*, é o coração do aprendizado. Ele processa os dados em pequenos grupos, chamados mini-lotes. Essa é uma abordagem mais eficiente e estável do que processar todos os dados de uma vez.
#
# Dentro desse loop, ocorrem os passos essenciais do treinamento:
#
# Reiniciar os Gradientes: **optimizer.zero_grad()** zera os gradientes acumulados do lote anterior. Pense nisso como "limpar o quadro-negro" antes de começar uma nova lição.
#
# Propagação Direta **(Forward Pass)**: *outputs = classificador(inputs)* executa o modelo. Ele recebe os dados de entrada (inputs) e produz uma previsão (outputs).
#
# Cálculo da Perda e** Retropropagação (Backward Pass)**: *loss = criterion(outputs, labels)* mede o "erro" da previsão comparando-a com o rótulo verdadeiro (labels). Em seguida,*** loss.backward()*** usa a retropropagação para calcular como cada peso do modelo contribuiu para esse erro.
#
# **Atualização dos Pesos: optimizer.step()** usa os gradientes calculados para ajustar os pesos do modelo, dando um pequeno passo na direção certa para reduzir a perda.
#
# **As linhas restantes (ps = F.softmax(outputs), topk, equals, e o print)** servem para monitorar o progresso do treinamento, calculando a acurácia e a perda de cada época e exibindo os resultados para que possamos acompanhar se o modelo está melhorando.

# %%
for epoch in range(200):

    running_loss = 0.
    running_accuracy = 0.

    for data in train_loader:
        inputs, labels = data

        optimizer.zero_grad()

        outputs = classificador(inputs)

        loss = criterion(outputs, labels)
        loss.backward()

        optimizer.step()

        running_loss += loss.item()

        ps = F.softmax(outputs)

        top_p, top_class = ps.topk(k = 1, dim = 1)

        equals = top_class == labels.view(*top_class.shape)

        running_accuracy += torch.mean(equals.type(torch.float))

    print('Época {:3d}: perda {:3.5f} - precisão {:3.5f}'.format(epoch + 1, running_loss/len(train_loader), running_accuracy/len(train_loader)))
# Out:
# /tmp/ipykernel_27350/3008167617.py:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   ps = F.softmax(outputs)
# Época   1: perda 1.29462 - precisão 0.33333
# Época   2: perda 1.20543 - precisão 0.38667
# Época   3: perda 1.16249 - precisão 0.41333
# Época   4: perda 1.08894 - precisão 0.48000
# Época   5: perda 1.02539 - precisão 0.53333
# Época   6: perda 0.95307 - precisão 0.58000
# Época   7: perda 0.92452 - precisão 0.62000
# Época   8: perda 0.95676 - precisão 0.54000
# Época   9: perda 0.85509 - precisão 0.62000
# Época  10: perda 0.89125 - precisão 0.62667
# Época  11: perda 0.83229 - precisão 0.63333
# Época  12: perda 0.81955 - precisão 0.62667
# Época  13: perda 0.79052 - precisão 0.64667
# Época  14: perda 0.72418 - precisão 0.68000
# Época  15: perda 0.67358 - precisão 0.66000
# Época  16: perda 0.69119 - precisão 0.69333
# Época  17: perda 0.65618 - precisão 0.68000
# Época  18: perda 0.60786 - precisão 0.76000
# Época  19: perda 0.56533 - precisão 0.78000
# Época  20: perda 0.61835 - precisão 0.69333
# Época  21: perda 0.56637 - precisão 0.78667
# Época  22: perda 0.57103 - precisão 0.72667
# Época  23: perda 0.58347 - precisão 0.72667
# Época  24: perda 0.55970 - precisão 0.76000
# Época  25: perda 0.52917 - precisão 0.75333
# Época  26: perda 0.51844 - precisão 0.78667
# Época  27: perda 0.51072 - precisão 0.77333
# Época  28: perda 0.47225 - precisão 0.80667
# Época  29: perda 0.49665 - precisão 0.77333
# Época  30: perda 0.51969 - precisão 0.79333
# Época  31: perda 0.44904 - precisão 0.82000
# Época  32: perda 0.47082 - precisão 0.78667
# Época  33: perda 0.43748 - precisão 0.83333
# Época  34: perda 0.48085 - precisão 0.80667
# Época  35: perda 0.40943 - precisão 0.84000
# Época  36: perda 0.42384 - precisão 0.85333
# Época  37: perda 0.38472 - precisão 0.88000
# Época  38: perda 0.39086 - precisão 0.86667
# Época  39: perda 0.39788 - precisão 0.81333
# Época  40: perda 0.46249 - precisão 0.82000
# Época  41: perda 0.42635 - precisão 0.83333
# Época  42: perda 0.32920 - precisão 0.90000
# Época  43: perda 0.35438 - precisão 0.89333
# Época  44: perda 0.35698 - precisão 0.84000
# Época  45: perda 0.35573 - precisão 0.86667
# Época  46: perda 0.31319 - precisão 0.88667
# Época  47: perda 0.31831 - precisão 0.90000
# Época 118: perda 0.24774 - precisão 0.89333
# Época 119: perda 0.15667 - precisão 0.93333
# Época 120: perda 0.19039 - precisão 0.92667
# Época 121: perda 0.17863 - precisão 0.92000
# Época 122: perda 0.15737 - precisão 0.96000
# Época 123: perda 0.19676 - precisão 0.91333
# Época 124: perda 0.19279 - precisão 0.90667
# Época 125: perda 0.18645 - precisão 0.94667
# Época 126: perda 0.21651 - precisão 0.91333
# Época 127: perda 0.22766 - precisão 0.92000
# Época 128: perda 0.19876 - precisão 0.93333
# Época 129: perda 0.16283 - precisão 0.96000
# Época 130: perda 0.18098 - precisão 0.94000
# Época 131: perda 0.18091 - precisão 0.96000
# Época 132: perda 0.14904 - precisão 0.94667
# Época 133: perda 0.16251 - precisão 0.94000
# Época 134: perda 0.18600 - precisão 0.93333
# Época 135: perda 0.20450 - precisão 0.90667
# Época 136: perda 0.21433 - precisão 0.90000
# Época 137: perda 0.15417 - precisão 0.96000
# Época 138: perda 0.20299 - precisão 0.94667
# Época 139: perda 0.15634 - precisão 0.95333
# Época 140: perda 0.21974 - precisão 0.90667
# Época 141: perda 0.17927 - precisão 0.94667
# Época 142: perda 0.18698 - precisão 0.92667
# Época 143: perda 0.18288 - precisão 0.94000
# Época 144: perda 0.14869 - precisão 0.96667
# Época 145: perda 0.15499 - precisão 0.94667
# Época 146: perda 0.18033 - precisão 0.94000
# Época 147: perda 0.25826 - precisão 0.90000
# Época 148: perda 0.21858 - precisão 0.90000
# Época 149: perda 0.16797 - precisão 0.95333
# Época 150: perda 0.17962 - precisão 0.93333
# Época 151: perda 0.16051 - precisão 0.94000
# Época 152: perda 0.21735 - precisão 0.89333
# Época 153: perda 0.20189 - precisão 0.92000
# Época 154: perda 0.21738 - precisão 0.89333
# Época 155: perda 0.15171 - precisão 0.95333
# Época 156: perda 0.15600 - precisão 0.94000
# Época 157: perda 0.23095 - precisão 0.91333
# Época 158: perda 0.18487 - precisão 0.94667
# Época 159: perda 0.14199 - precisão 0.94000
# Época 160: perda 0.16215 - precisão 0.92000
# Época 161: perda 0.14174 - precisão 0.94667
# Época 162: perda 0.21603 - precisão 0.92667
# Época 163: perda 0.19260 - precisão 0.91333
# Época 164: perda 0.17040 - precisão 0.94667
# Época 165: perda 0.13855 - precisão 0.96000
# Época 166: perda 0.14799 - precisão 0.95333
# Época 167: perda 0.19223 - precisão 0.92667
# Época 168: perda 0.19350 - precisão 0.93333
# Época 169: perda 0.14337 - precisão 0.94667
# Época 170: perda 0.15405 - precisão 0.94667
# Época 171: perda 0.14209 - precisão 0.94000
# Época 172: perda 0.23785 - precisão 0.88667
# Época 173: perda 0.21201 - precisão 0.94000
# Época 174: perda 0.18438 - precisão 0.93333
# Época 175: perda 0.13974 - precisão 0.96000
# Época 176: perda 0.15039 - precisão 0.94000
# Época 177: perda 0.18331 - precisão 0.92667
# Época 178: perda 0.15551 - precisão 0.92667
# Época 179: perda 0.17466 - precisão 0.94000
# Época 180: perda 0.13807 - precisão 0.94000
# Época 181: perda 0.18443 - precisão 0.93333
# Época 182: perda 0.18699 - precisão 0.94000
# Época 183: perda 0.14371 - precisão 0.96000
# Época 184: perda 0.15614 - precisão 0.96000
# Época 185: perda 0.16281 - precisão 0.94000
# Época 186: perda 0.16521 - precisão 0.94667
# Época 187: perda 0.19239 - precisão 0.91333
# Época 188: perda 0.16991 - precisão 0.94667
# Época 189: perda 0.17503 - precisão 0.94000
# Época 190: perda 0.16059 - precisão 0.92667
# Época 191: perda 0.17420 - precisão 0.92667
# Época 192: perda 0.16732 - precisão 0.91333
# Época 193: perda 0.17698 - precisão 0.93333
# Época 194: perda 0.15202 - precisão 0.94000
# Época 195: perda 0.14746 - precisão 0.95333
# Época 196: perda 0.16424 - precisão 0.96000
# Época 197: perda 0.18705 - precisão 0.92000
# Época 198: perda 0.16972 - precisão 0.94000
# Época 199: perda 0.18889 - precisão 0.95333
# Época 200: perda 0.14468 - precisão 0.94667

# %% [markdown]
# ## Etapa 5: Salvar e carregar o classificador e classificar um registro

# %%
torch.save(classificador.state_dict(), 'checkpoint_exer2_computer.pth')

# %%
state_dict = torch.load('checkpoint_exer2_computer.pth')
classificador.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %% [markdown]
# ** 1)** Preparando os Dados e o Modelo
# **negrito**
#
# novo = torch.tensor([[3.2, 4.5, 0.9, 1.1]], requires_grad = False)
# classificador.eval() *texto em itálico*
#
# novo = ...: Cria um novo tensor que representa uma única amostra de dados. Os valores [3.2, 4.5, 0.9, 1.1] são as **características (ou features**) dessa amostra. O argumento requires_grad = False é importante porque, *como não estamos treinando, não precisamos calcular gradientes*, o que economiza tempo e memória.
#
# **classificador.eval()**: Coloca o modelo (classificador) no modo de avaliação. Isso é essencial porque desativa camadas que se comportam de forma diferente durante o treinamento (como Dropout e BatchNorm), garantindo que o modelo produza resultados consistentes e confiáveis.

# %% [markdown]
# **2. Executando a Previsão**
#
# previsao = classificador(novo)
# previsao = F.softmax(previsao)
# previsao = (previsao > 0.5).numpy() *texto em itálico*
#
# **previsao = classificador(novo):** A amostra novo é passada para o modelo treinado. O modelo faz uma passagem direta (forward pass) e retorna os valores brutos de saída para cada classe.
#
# **previsao = F.softmax(previsao): ** A função softmax converte os valores brutos de saída em probabilidades, garantindo que a soma de todas as probabilidades seja 1. Por exemplo, a saída pode se tornar [0.1, 0.9, 0.0].
#
# **previsao = (previsao > 0.5).numpy():** Esta linha converte as probabilidades em um array binário (True ou False). O valor True é atribuído a qualquer classe com probabilidade maior que 50% (0.5), enquanto o restante é False. O resultado seria algo como [[False, True, False]].

# %% [markdown]
# **3. Convertendo a Previsão em Texto**
#
#
# if previsao[0][0] == True ...
#     print('Iris setosa')
# elif previsao[0][0] == False and previsao[0][1] == True ...
#     print('Iris virginica')
# elif previsao[0][0] == False and previsao[0][1] == False and previsao[0][2] == True:
#     print('Iris versicolor') *texto em itálico*
#
# Este bloco de código if/elif analisa o array binário da previsão para determinar qual classe tem o valor True. Com base nisso, ele imprime o nome da espécie de íris correspondente. Por exemplo, se o array for [[False, True, False]], o segundo elif será ativado, e a mensagem 'Iris virginica' será exibida.

# %%
novo = torch.tensor([[3.2, 4.5, 0.9, 1.1]], requires_grad = False)
classificador.eval()
previsao = classificador(novo)
previsao = F.softmax(previsao)
previsao = (previsao > 0.5).numpy()
if previsao[0][0] == True and previsao[0][1] == False and previsao[0][2] == False:
    print('Iris setosa')
elif previsao[0][0] == False and previsao[0][1] == True and previsao[0][2] == False:
    print('Iris virginica')
elif previsao[0][0] == False and previsao[0][1] == False and previsao[0][2] == True:
    print('Iris versicolor')
# Out:
# Iris setosa
# /tmp/ipykernel_27350/2632930173.py:4: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   previsao = F.softmax(previsao)
