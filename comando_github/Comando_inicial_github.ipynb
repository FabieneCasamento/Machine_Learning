# %%
# Processo de comandos no github

# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git init
# Reinitialized existing Git repository in /home/casamentos/Documentos/GitHub/Machine_Learning/.git/
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git fetch
# From https://github.com/FabieneCasamento/Machine_Learning
#  * [new branch]      new_branch_fix2 -> origin/new_branch_fix2
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git branch -r origin/HEAD -> origin/fix2
# bash: origin/fix2: Arquivo ou diretório inexistente
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git branch --set-upstream-to=origin/new_branch_fix2
# Branch 'fix2' set up to track remote branch 'new_branch_fix2' from 'origin'.
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ 

# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git pull origin new_branch_fix2


# # deixar o commit limpo 
# git pull --rebase


# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git branch -a
# * fix2
#   fix3
#   main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/fix2
#   remotes/origin/main
#   remotes/origin/new_branch_fix2

# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git checkout -t origin/new_branch_fix2


# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git add Machine_Learning_AZ/19-Visao_Computacional/M25-5_Rastreamento-parte2-ver2.ipynb 
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git commit -m 'atualizacao objeto rastreamento'
# [new_branch_fix2 87333f3] atualizacao objeto rastreamento
#  1 file changed, 254 insertions(+)
#  create mode 100755 Machine_Learning_AZ/19-Visao_Computacional/M25-5_Rastreamento-parte2-ver2.ipynb
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git push
# Enumerating objects: 8, done.
# Counting objects: 100% (8/8), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 3.41 MiB | 37.96 MiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/FabieneCasamento/Machine_Learning.git
#    codigo new_branch_fix2 -> new_branch_fix2
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$ git config http.postBuffer 300000000
# (base) casamentos@:~/Documentos/GitHub/Machine_Learning$
