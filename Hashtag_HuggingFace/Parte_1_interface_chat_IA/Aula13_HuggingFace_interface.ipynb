# %%
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python

# %%
# sys.executable mostra que você está usando o ambiente 'orange3' do Anaconda.
# Isso é importante para saber quais bibliotecas estão instaladas.
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python

# %%
# --- IMPORTAÇÃO ---
# Procura o arquivo 'main.py' e traz a função 'main_app' para este script.
# Isso permite que usemos as funcionalidades criadas lá sem repetir código.
#from main import main_app

# %%
#!pip install streamlit

# %% [markdown]
# Processo Hugging Face
#
# Chat para no python. Hash IAs
#
# Interface visual do HashIAs com Streamlit
#
# Criar terla no streamlit

# %% [markdown]
# Abrir um terminal http://localhost:8889/terminals/1

# %% [markdown]
# ### exemplo da plataforma

# %% [markdown]
#  pwd
#
# /home/fabiene/Documentos/Fabiene/PYTHON_CURSO_LIRA_C2/Agente_de_inteligenciaArtificial/Hugging_Face/Aula_interface
#
# no terminal para rodar =>
# streamlit run main.py

# %% [markdown]
# ![image.png](attachment:caf7ba43-9ad6-4523-80f7-c5f5eb91389d.png)

# %%
#conda env list

#conda activate orange3

#streamlit run main.py

# %%
def buscar_token(arquivo):
    with open(arquivo, 'r') as f:
        for linha in f:
            if 'HF_TOKEN' in linha:
                # Divide no '=' e remove espaços ou quebras de linha
                return linha.split('=')[1].strip()

# Uso:
meu_token = buscar_token('../env')
#print(meu_token) # senha token

# %%
from huggingface_hub import InferenceClient
from dotenv import load_dotenv
import streamlit as st
from hfapi_summarization import resumir

load_dotenv()
cliente = InferenceClient(token=meu_token, model="facebook/bart-large-cnn")

# %%
main_app

# %% [markdown]
# Texto_curso_ingles= """
#
# Nowadays, we are still uncovering the full capabilities of the human brain. While it is a common myth that we use only a small fraction of our brain, research shows that nearly all regions are active, even when we are at rest. The debunking of this myth doesn't detract from the knowledge that our brains have vast potential.
#
# The brain is an incredibly complex organ. The huge number of neurones the brain contains has been compared to the number of stars in the Milky Way - with the connections between these neurones forming seemingly endless intricate networks that shape our many thoughts, emotions, and abilities.
#
# Most of us are aware that we possess a left and a right brain and that these hemispheres are often associated with different functions. It has, however, been discovered that although there are some tasks that can be associated with using slightly more of different sides of the brain, it is far more common for both sides to work together. This means that the whole brain can be involved in creative tasks as well as more logical ones.
#
# Rather than seeing ourselves as 'left-brained' or 'right-brained,' we should focus on developing a balance of skills. If we look at a famous historical figure such as Leonardo da Vinci, who was considered a genius for combining artistic mastery with scientific enquiry, we can see that a combination is the most effective. By embracing the brain’s full potential, we can expand our capabilities in ways we are only beginning to understand.
# """

# %% [markdown]
# ![image.png](attachment:151c1e6d-e4c0-4bb0-8c82-a965c2f93229.png)
