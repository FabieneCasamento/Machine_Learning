# %% [markdown]
# ## Criar conta Hug de inteligência artificial
#
# https://huggingface.co/

# %% [markdown]
# ## ir na parte de model de inteligência artificial
#
# https://huggingface.co/models
#
# ![image.png](attachment:1b00ac40-92d1-453b-b8da-36513287f7eb.png)

# %% [markdown]
# usando servidores do hugging face cobrando a taxa, dinheiro
#
# baixar para rodar no meu computador, não enviando para a ia externo, e sim interno no meu computador

# %%
#Ir no ambiente orange3

#no linux:

#conda activate orange3

#conda env list

# conda environments:
#
#base                     /home/fabiene/anaconda3
#Maq2                     /home/fabiene/anaconda3/envs/Maq2
#RBA_est                  /home/fabiene/anaconda3/envs/RBA_est
#Robyn                    /home/fabiene/anaconda3/envs/Robyn
#Udemy                    /home/fabiene/anaconda3/envs/Udemy
#YouTube                  /home/fabiene/anaconda3/envs/YouTube
#face-env                 /home/fabiene/anaconda3/envs/face-env
#orange3               *  /home/fabiene/anaconda3/envs/orange3
#pycaret-env              /home/fabiene/anaconda3/envs/pycaret-en

# %% [markdown]
# base de dados do dataset
#
# ![image.png](attachment:f989de20-2760-461c-a9fe-ce329d978e15.png)

# %%
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python

# %% [markdown]
# ## É necessário usar ou o pytorch ou tensorflow da rede neural, para trabalhar com volumes de dado em larga escala

# %% [markdown]
# https://pytorch.org/
#
#
# ![image.png](attachment:dec9e58c-55e4-457a-b7f0-40c80d11f5b6.png)

# %%
# cuda placa de vídeo da nvidia, rápido no processamento.

# %%
print(sys.version)
# Out:
# 3.10.18 (main, Jun  5 2025, 13:14:17) [GCC 11.2.0]

# %%
# !nvidia-smi # não é usado a placa nvidia
# Out:
# /bin/bash: linha 1: nvidia-smi: comando não encontrado

# %%
# !nvcc --version
# Out:
# /bin/bash: linha 1: nvcc: comando não encontrado

# %%
#!pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# tive que usar da cpu mesmo
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 3.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.4/184.4 MB 3.8 MB/s  0:00:50 eta 0:00:010:00:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.0 MB/s  0:00:00m 4.0 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 749.4 kB/s  0:00:08 eta 0:00:010:02:03
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [torchvision] 5/6 [torchvision]]
# ...
