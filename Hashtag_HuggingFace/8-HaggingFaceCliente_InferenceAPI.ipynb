# %% [markdown]
# conda activate orange3

# %% [markdown]
# ### Inference API e Inference Client - usando modelos sem baixar

# %% [markdown]
# usar a interface do hugginfFace sem deixar na máquina

# %%
import sys
print(sys.executable)
# Out:
# /home/fabiene/anaconda3/envs/orange3/bin/python

# %% [markdown]
# https://huggingface.co/models

# %% [markdown]
# inference usage U$ 0.10
#
# ![image.png](attachment:b2d4174d-01f1-4637-8342-c6b269e4e5b8.png)

# %% [markdown]
# ou no billing
# ![image.png](attachment:53224c6d-3518-430a-a6ad-2034c79ac4c4.png)

# %% [markdown]
# https://huggingface.co/settings/billing

# %% [markdown]
# exemplos com modelos de texto, é mais barato

# %% [markdown]
# antes havia o
#
# ![image.png](attachment:e882c82a-af72-48ce-94e4-926be985b766.png)

# %% [markdown]
# https://huggingface.co/docs
#
# https://huggingface.co/docs/inference-providers/index
#
# Hugging Face’s Inference Providers give developers access to hundreds of machine learning models, powered by world-class inference providers. They are also integrated into our client SDKs (for JS and Python), making it easy to explore serverless inference of models on your favorite providers.

# %% [markdown]
# ![image.png](attachment:d95c6bfe-a060-4d28-8a34-73adeb327024.png)

# %% [markdown]
# ideal fazer pelo inferenceClient
#
# ![image.png](attachment:c34521a9-efd9-40ca-8afd-6daa62efa638.png)

# %% [markdown]
# Getting Started

# %% [markdown]
# https://huggingface.co/docs/inference-providers/index#getting-started

# %%
#!pip install huggingface-hub

# %%
import os
from huggingface_hub import InferenceClient

# %%
client = InferenceClient()

# %% [markdown]
# precisamoos do HF_TOKEN no computador

# %%
# instalar para o HF_TOKEN
#!pip install python-dotenv

# %%
# para ler o token
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# usar o meu .env em doc
#
# OPENAI_API_KEY=
#
# HF_TOKEN=

# %%
from huggingface_hub import InferenceClient

# Substitua 'SEU_TOKEN_AQUI' pelo código que você copiou do site
#meu_token = "hf_xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx"

#cliente = InferenceClient(token=meu_token)

# Busca o valor da variável HF_TOKEN
meu_token = os.getenv("HF_TOKEN")

# Agora você usa o token sem expor o texto dele no código
cliente = InferenceClient(token=meu_token)

# %%
#cliente = InferenceClient()

# %%
def buscar_token(arquivo):
    with open(arquivo, 'r') as f:
        for linha in f:
            if 'HF_TOKEN' in linha:
                # Divide no '=' e remove espaços ou quebras de linha
                return linha.split('=')[1].strip()

# Uso:
meu_token = buscar_token('env')
cliente = InferenceClient(token=meu_token)

# %%
#meu_token

# %% [markdown]
# ### summarization => resumir o texto
#
# resumir o alfabeto grego

# %%
texto = """Greek (Modern Greek: Ελληνικά, romanized: Elliniká, [eliniˈka]; Ancient Greek: Ἑλληνική, romanized: Hellēnikḗ) is an Indo-European language, constituting an independent Hellenic branch within the Indo-European language family. It is native to Greece, Cyprus, Italy (in Calabria and Salento), southern Albania, and other regions of the Balkans, Caucasus, the Black Sea coast, Asia Minor, and the Eastern Mediterranean. It has the longest documented history of any Indo-European language, spanning at least 3,400 years of written records.[10] Its writing system is the Greek alphabet, which has been used for approximately 2,800 years;[11][12] previously, Greek was recorded in writing systems such as Linear B and the Cypriot syllabary.[13] The alphabet arose from the Phoenician script and was in turn the basis of the Latin, Cyrillic, Coptic, Gothic, and many other writing systems.

The Greek language holds a very important place in the history of the Western world. Beginning with the epics of Homer, ancient Greek literature includes many works of lasting importance in the European canon. Greek is also the language in which many of the foundational texts in science and philosophy were originally composed. The New Testament of the Christian Bible was also originally written in Greek.[14][15] Together with the Latin texts and traditions of the Roman world, the Greek texts and Greek societies of antiquity constitute the objects of study of the discipline of Classics.

During antiquity, Greek was by far the most widely spoken lingua franca in the Mediterranean world.[16] It eventually became the official language of the Byzantine Empire and developed into Medieval Greek.[17] In its modern form, Greek is the official language of Greece and Cyprus and one of the 24 official languages of the European Union. It is spoken by at least 13.5 million people today in Greece, Cyprus, Italy, Albania, Turkey, and the many other countries of the Greek diaspora.

Greek roots have been widely used for centuries and continue to be widely used to coin new words in other languages; Greek and Latin are the predominant sources of international scientific vocabulary."""

resposta = cliente.summarization(texto, model="facebook/bart-large-cnn")
print(resposta)
# Out:
# SummarizationOutput(summary_text='Greek is an Indo-European language. It is native to Greece, Cyprus, Italy (in Calabria and Salento), southern Albania, and other regions of the Balkans, Caucasus, the Black Sea coast, Asia Minor, and the Eastern Mediterranean. Its writing system is the Greek alphabet, which has been used for approximately 2,800 years. In its modern form, Greek is the official language of Greece and Cyprus.')

# %% [markdown]
# -------------------
# ## Why Choose Inference Providers?
#
# Traditional ML Tasks: Ready-to-use models for classification, NER, summarization, and speech recognition

# %% [markdown]
# modelo recomendado no summarization: https://huggingface.co/facebook/bart-large-cnn

# %%
# tab
#resposta = cliente.

# %% [markdown]
# ![image.png](attachment:39b5ce48-ca70-4aa9-a0ab-32edab25fc45.png)

# %%
# completion = client.chat.completions.create(
#     model="openai/gpt-oss-120b",
#     messages=[
#         {
#             "role": "user",
#             "content": "How many 'G's in 'huggingface'?"
#         }
#     ],
# )

# print(completion.choices[0].message)

# %%
# import { InferenceClient } from "@huggingface/inference";

# const client = new InferenceClient(process.env.HF_TOKEN);

# const chatCompletion = await client.chatCompletion({
#   model: "openai/gpt-oss-120b:fastest",
#   messages: [
#     {
#       role: "user",
#       content: "How many 'G's in 'huggingface'?",
#     },
#   ],
# });

# console.log(chatCompletion.choices[0].message);

# %% [markdown]
# token: https://huggingface.co/docs/hub/en/security-tokens

# %% [markdown]
# access token
#
# ![image.png](attachment:b40a46e1-6a36-459a-9f37-eeadb6af43c2.png)

# %% [markdown]
# create new token
# ![image.png](attachment:35c8019f-0e08-4752-ba59-b5d969f91975.png)

# %% [markdown]
# https://huggingface.co/docs
#
# https://huggingface.co/docs/inference-providers/index#getting-started
#
# https://huggingface.co/settings/tokens
#
# explicar: https://huggingface.co/docs/hub/en/security-tokens

# %% [markdown]
# resend confirmation email
#
# ![image.png](attachment:7cde945c-e24b-4d4b-bc64-fc1308ada031.png)
