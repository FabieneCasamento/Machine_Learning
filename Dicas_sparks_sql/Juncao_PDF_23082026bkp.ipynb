# %%
# ambiente linux Udemy
#conda info --envs
# ou
#conda env list

# %%
import sys

print(sys.executable)
#/home/fabiene/anaconda3/envs/Udemy/bin/python
# Out:
# /home/fabiene/anaconda3/envs/Udemy/bin/python

# %%
#!pip install pypdf

# %%
from pypdf import PdfWriter

merger = PdfWriter()

# Adicione os arquivos na ordem desejada
for pdf in ["Carteira_motorista_fabiene.pdf", "certidao_nascimento.pdf", "cpf.pdf", "RGE.pdf", "RGE2.pdf", "endereco.pdf"]:
    merger.append(pdf)

merger.write("documentacao_completa_fabiene.pdf")
merger.close()
